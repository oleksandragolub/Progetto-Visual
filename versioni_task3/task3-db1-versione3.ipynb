# %% [markdown]
# # **Visual Information Processing and Management**
# ---
# ---
#
# Università degli Studi Milano Bicocca \
# CdLM Informatica — A.A 2025/2026
#
# ---
# ---
#
# ### **Componenti del gruppo:**
# — Oleksandra Golub (856706) \
# — Andrea Spagnolo (879254)

# %% [markdown]
# ## **Librerie**

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image, ImageOps
from dataclasses import dataclass
from typing import List, Tuple

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.base import clone
from skimage import exposure
from skimage.restoration import denoise_bilateral
from sklearn.decomposition import PCA

from skimage.feature import hog, local_binary_pattern
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from torchvision import datasets

# %% [markdown]
# ## **Configurazione + Device**

# %%
@dataclass
class Config:
    # paths
    data_dir = "/kaggle/input/datasets/andreaspagnolo/visual-exam-dataset/visual_dataset"
    #data_dir: str = "/kaggle/input/visual-exam-dataset/visual_dataset"
    fit_dir  = "/kaggle/input/datasets/andreaspagnolo/visual-exam-dataset/visual_dataset/valid"
    #fit_dir: str = "/kaggle/input/visual-exam-dataset/visual_dataset/valid"
    test_dir = "/kaggle/input/datasets/andreaspagnolo/visual-exam-dataset/visual_dataset/test_degradato"
    #test_dir: str = "/kaggle/input/visual-exam-dataset/visual_dataset/test_degradato"
    cache_dir = "/kaggle/working/feat_cache"
    
    img_size = 128   # per HOG spesso 128 va benissimo

    # ===== preprocessing =====
    use_preprocess = True
    use_grayworld = False          # per degradato spesso può fare danni → default OFF
    use_autocontrast = False       # lo sostituiamo con CLAHE
    use_clahe = True
    clahe_clip_limit = 0.01        # 0.01–0.03 di solito ok; aumenta se immagini “piatte”
    use_denoise = True
    denoise_sigma_color = 0.05     # leggero
    denoise_sigma_spatial = 2      # leggero

    # ===== HOG params (default, poi li tuneremo) =====
    hog_orientations = 9
    hog_pixels_per_cell = (8, 8)
    hog_cells_per_block = (2, 2)
    hog_transform_sqrt = True

    # ===== tuning =====
    test_size_internal = 0.2
    random_state = 42
    C_grid = (0.1, 0.3, 1.0, 3.0, 10.0)
    max_iter = 50000

    # ===== PCA =====
    use_pca = True
    pca_components_grid = (256, 512, 1024)  # filtreremo automaticamente quelli non validi

def sanity_check_paths(cfg: Config):
    for p in [cfg.data_dir, cfg.fit_dir, cfg.test_dir]:
        if not os.path.exists(p):
            raise FileNotFoundError(f"Path not found: {p}")
    print("OK paths")
    print("fit_dir:", cfg.fit_dir)
    print("test_dir:", cfg.test_dir)

# %%
def ensure_cache_dir(cfg):
    os.makedirs(cfg.cache_dir, exist_ok=True)

def feature_signature(cfg, mode: str) -> str:
    return (
        f"{mode}"
        f"_img{cfg.img_size}"
        f"_pre{int(cfg.use_preprocess)}"
        f"_clahe{int(cfg.use_clahe)}c{cfg.clahe_clip_limit}"
        f"_den{int(cfg.use_denoise)}sc{cfg.denoise_sigma_color}ss{cfg.denoise_sigma_spatial}"
        f"_hogO{cfg.hog_orientations}"
        f"_hogpc{cfg.hog_pixels_per_cell[0]}x{cfg.hog_pixels_per_cell[1]}"
        f"_hogcb{cfg.hog_cells_per_block[0]}x{cfg.hog_cells_per_block[1]}"
        f"_hogsqrt{int(cfg.hog_transform_sqrt)}"
    )


def cache_paths(cfg, mode: str):
    sig = feature_signature(cfg, mode)
    fit_path  = os.path.join(cfg.cache_dir, f"Xy_fit_{sig}.npz")
    test_path = os.path.join(cfg.cache_dir, f"Xy_test_{sig}.npz")
    return fit_path, test_path

def load_xy_npz(path: str):
    data = np.load(path)
    return data["X"], data["y"]

def save_xy_npz(path: str, X: np.ndarray, y: np.ndarray):
    np.savez_compressed(path, X=X, y=y)

# %% [markdown]
# ## **Preprocessing**

# %%
class GrayWorldWB:
    def __call__(self, img: Image.Image) -> Image.Image:
        arr = np.asarray(img).astype(np.float32)
        mean = arr.mean(axis=(0, 1), keepdims=True)
        arr = arr / (mean + 1e-6)
        arr = arr / (arr.max() + 1e-6)
        return Image.fromarray((arr * 255).astype(np.uint8))

class AutoContrast:
    def __call__(self, img: Image.Image) -> Image.Image:
        return ImageOps.autocontrast(img, cutoff=1)

def preprocess_pil(img: Image.Image, cfg: Config) -> Image.Image:
    if not cfg.use_preprocess:
        return img
    if cfg.use_grayworld:
        img = GrayWorldWB()(img)
    if cfg.use_autocontrast:
        img = AutoContrast()(img)
    return img


def preprocess_gray(img_gray: np.ndarray, cfg: Config) -> np.ndarray:
    """
    img_gray: uint8 [0..255]
    ritorna uint8 [0..255]
    """
    if not cfg.use_preprocess:
        return img_gray

    x = img_gray.astype(np.float32) / 255.0

    # Denoise leggero (bilateral) aiuta su rumore e degradazione
    if cfg.use_denoise:
        x = denoise_bilateral(
            x,
            sigma_color=cfg.denoise_sigma_color,
            sigma_spatial=cfg.denoise_sigma_spatial,
            channel_axis=None
        )

    # CLAHE (adaptive histogram equalization)
    if cfg.use_clahe:
        x = exposure.equalize_adapthist(x, clip_limit=cfg.clahe_clip_limit)

    x = np.clip(x, 0, 1)
    return (x * 255).astype(np.uint8)

# %% [markdown]
# ## **Feature Extraction**

# %%
def feat_hog(path: str, cfg: Config) -> np.ndarray:
    img = Image.open(path).convert("RGB")
    img = img.resize((cfg.img_size, cfg.img_size))
    img_gray = np.array(img.convert("L"))

    img_gray = preprocess_gray(img_gray, cfg)

    return hog(
        img_gray,
        orientations=cfg.hog_orientations,
        pixels_per_cell=cfg.hog_pixels_per_cell,
        cells_per_block=cfg.hog_cells_per_block,
        block_norm="L2-Hys",
        transform_sqrt=cfg.hog_transform_sqrt,
        feature_vector=True
    ).astype(np.float32)

def feat_lbp(path: str, cfg: Config, P: int = 8, R: int = 1) -> np.ndarray:
    img = Image.open(path).convert("RGB")
    img = preprocess_pil(img, cfg)
    img = img.resize((cfg.img_size, cfg.img_size))
    img_gray = np.array(img.convert("L"))

    lbp = local_binary_pattern(img_gray, P=P, R=R, method="uniform")
    n_bins = P + 2
    hist, _ = np.histogram(lbp.ravel(), bins=np.arange(0, n_bins + 1), range=(0, n_bins))
    hist = hist.astype(np.float32)
    hist /= (hist.sum() + 1e-8)
    return hist

def feat_hog_lbp(path: str, cfg: Config) -> np.ndarray:
    return np.concatenate([feat_hog(path, cfg), feat_lbp(path, cfg)], axis=0)

# %% [markdown]
# ## **Dataset**

# %%
def build_xy(folder: datasets.ImageFolder, cfg: Config, mode: str) -> Tuple[np.ndarray, np.ndarray]:
    X, y = [], []
    for path, label in folder.samples:
        if mode == "hog":
            X.append(feat_hog(path, cfg))
        elif mode == "lbp":
            X.append(feat_lbp(path, cfg))
        elif mode == "hog+lbp":
            X.append(feat_hog_lbp(path, cfg))
        else:
            raise ValueError("mode must be: 'hog', 'lbp', 'hog+lbp'")
        y.append(label)
    return np.asarray(X), np.asarray(y)

# %% [markdown]
# ## **Evaluation su test + Matrice di confusione**

# %%
def plot_confusion_matrix(cm: np.ndarray, title: str = "Confusion Matrix (normalized)"):
    cm_norm = cm.astype(np.float32) / np.maximum(cm.sum(axis=1, keepdims=True), 1)

    plt.figure(figsize=(18, 16))
    sns.heatmap(cm_norm, cmap="viridis", xticklabels=False, yticklabels=False)
    plt.title(title)
    plt.xlabel("Predicted label")
    plt.ylabel("True label")
    plt.tight_layout()
    plt.show()


def print_top_confusions(cm: np.ndarray, class_names: List[str], top_k: int = 100):
    cm_no_diag = cm.copy()
    np.fill_diagonal(cm_no_diag, 0)

    pairs = []
    for i in range(len(class_names)):
        for j in range(len(class_names)):
            if i != j and cm_no_diag[i, j] > 0:
                pairs.append((i, j, cm_no_diag[i, j]))

    pairs_sorted = sorted(pairs, key=lambda x: x[2], reverse=True)

    print(f"\nTop {top_k} coppie più confuse:\n")
    for i, j, value in pairs_sorted[:top_k]:
        print(f"{class_names[i]} → {class_names[j]}  | {value} errori")

def tune_and_test_model(X_fit, y_fit, X_test, y_test, cfg: Config, model_name: str, base_pipe: Pipeline, param_grid: dict):
    # split interno sul VALID
    X_tr, X_val, y_tr, y_val = train_test_split(
        X_fit, y_fit,
        test_size=cfg.test_size_internal,
        random_state=cfg.random_state,
        stratify=y_fit
    )

    best_params = None
    best_f1 = -1.0
    best_pipe = None

    # grid search manuale (semplice e controllabile)
    # param_grid: dict tipo {"svm__C":[...], "knn__n_neighbors":[...]}
    keys = list(param_grid.keys())
    values = list(param_grid.values())

    def product(lst):
        if not lst:
            return [()]
        out = [()]
        for v in lst:
            out = [x + (y,) for x in out for y in v]
        return out

    for combo in product(values):
        pipe = clone(base_pipe)
        params = {k: combo[i] for i, k in enumerate(keys)}
        pipe.set_params(**params)

        pipe.fit(X_tr, y_tr)
        y_val_pred = pipe.predict(X_val)

        f1 = f1_score(y_val, y_val_pred, average="macro", zero_division=0)
        if f1 > best_f1:
            best_f1 = f1
            best_params = params
            best_pipe = pipe

    # fit finale su TUTTO il VALID
    final_pipe = clone(base_pipe)
    if best_params is not None:
        final_pipe.set_params(**best_params)

    final_pipe.fit(X_fit, y_fit)
    y_pred = final_pipe.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    f1  = f1_score(y_test, y_pred, average="macro", zero_division=0)
    cm  = confusion_matrix(y_test, y_pred)

    return best_params, best_f1, acc, f1, cm, final_pipe


def get_or_build_xy(folder, cfg, mode: str, split_name: str):
    """
    split_name: "fit" o "test"
    """
    ensure_cache_dir(cfg)
    fit_path, test_path = cache_paths(cfg, mode)
    path = fit_path if split_name == "fit" else test_path

    if os.path.exists(path):
        print(f"[CACHE HIT] {split_name} {mode} -> {path}")
        return load_xy_npz(path)

    print(f"[CACHE MISS] calcolo feature per {split_name} {mode}...")
    X, y = build_xy(folder, cfg, mode) 
    save_xy_npz(path, X, y)
    print(f"[CACHE SAVE] {split_name} {mode} -> {path}")
    return X, y

# %%
def get_models(cfg: Config, pca_n_components_list, use_pca_now: bool):

    models = {}

    # blocco PCA opzionale
    pca_step = []
    if use_pca_now:
        pca_step = [("pca", PCA(n_components=pca_n_components_list[0], svd_solver="randomized", random_state=cfg.random_state))]

    # 1) LinearSVC
    models["LinearSVC"] = (
        Pipeline([("scaler", StandardScaler())] + pca_step + [("clf", LinearSVC(max_iter=cfg.max_iter))]),
        {
            "clf__C": list(cfg.C_grid),
            **({"pca__n_components": pca_n_components_list} if use_pca_now else {})
        }
    )

    # 2) Logistic Regression
    models["LogReg"] = (
        Pipeline([("scaler", StandardScaler())] + pca_step + [("clf", LogisticRegression(max_iter=5000, n_jobs=-1))]),
        {
            "clf__C": list(cfg.C_grid),
            **({"pca__n_components": pca_n_components_list} if use_pca_now else {})
        }
    )

    # 3) RidgeClassifier (molto veloce)
   # models["Ridge"] = (
   #     Pipeline([("scaler", StandardScaler()),
   #               ("clf", RidgeClassifier())]),
   #     {"clf__alpha": [0.1, 1.0, 3.0, 10.0]}
   # )

    # 4) KNN (scale obbligatoria)
  #  models["KNN"] = (
   #     Pipeline([("scaler", StandardScaler()),
   #               ("clf", KNeighborsClassifier())]),
   #     {"clf__n_neighbors": [3, 5, 11, 21], "clf__weights": ["uniform", "distance"]}
   # )

    # 5) RandomForest (NON serve scaler, ma non fa male tenerlo fuori)
    # Qui faccio pipeline senza scaler
  #  models["RF"] = (
  #      Pipeline([("clf", RandomForestClassifier(random_state=cfg.random_state, n_jobs=-1))]),
   #     {"clf__n_estimators": [200, 500], "clf__max_depth": [None, 20, 40]}
   # )

    # 6) Naive Bayes (GaussianNB) – spesso ok su feature dense
  #  models["GNB"] = (
  #      Pipeline([("scaler", StandardScaler()),
  #                ("clf", GaussianNB())]),
  #      {}  # niente iperparametri principali
  #  )

    return models

# %%
hog_grid = [
    dict(hog_orientations=9,  hog_pixels_per_cell=(8,8),  hog_cells_per_block=(2,2), hog_transform_sqrt=True),
    dict(hog_orientations=12, hog_pixels_per_cell=(8,8),  hog_cells_per_block=(2,2), hog_transform_sqrt=True),
    dict(hog_orientations=9,  hog_pixels_per_cell=(16,16),hog_cells_per_block=(2,2), hog_transform_sqrt=True),
    dict(hog_orientations=12, hog_pixels_per_cell=(16,16),hog_cells_per_block=(2,2), hog_transform_sqrt=True),
    dict(hog_orientations=9,  hog_pixels_per_cell=(16,16),hog_cells_per_block=(3,3), hog_transform_sqrt=True),
]

# %%
pre_pca_grid = [
    {"use_preprocess": False, "use_pca": False, "tag": "PRE0_PCA0"},
    {"use_preprocess": False, "use_pca": True,  "tag": "PRE0_PCA1"},
    {"use_preprocess": True,  "use_pca": False, "tag": "PRE1_PCA0"},
    {"use_preprocess": True,  "use_pca": True,  "tag": "PRE1_PCA1"},
]

# %% [markdown]
# ## **Main**

# %%
cfg = Config()
np.random.seed(cfg.random_state)
sanity_check_paths(cfg)
# Out:
# OK paths
# fit_dir: /kaggle/input/datasets/andreaspagnolo/visual-exam-dataset/visual_dataset/valid
# test_dir: /kaggle/input/datasets/andreaspagnolo/visual-exam-dataset/visual_dataset/test_degradato

# %%
fit_ds  = datasets.ImageFolder(cfg.fit_dir)   # VALID come training del task3
test_ds = datasets.ImageFolder(cfg.test_dir)

print("Fit classes:", fit_ds.classes)
print("Test classes:", test_ds.classes)
assert fit_ds.classes == test_ds.classes, "ATTENZIONE: class order diverso tra fit e test!"

class_names = fit_ds.classes
# Out:
# Fit classes: ['air hockey', 'ampute football', 'archery', 'arm wrestling', 'axe throwing', 'balance beam', 'barell racing', 'baseball', 'basketball', 'baton twirling', 'bike polo', 'billiards', 'bmx', 'bobsled', 'bowling', 'boxing', 'bull riding', 'bungee jumping', 'canoe slamon', 'cheerleading', 'chuckwagon racing', 'cricket', 'croquet', 'curling', 'disc golf', 'fencing', 'field hockey', 'figure skating men', 'figure skating pairs', 'figure skating women', 'fly fishing', 'football', 'formula 1 racing', 'frisbee', 'gaga', 'giant slalom', 'golf', 'hammer throw', 'hang gliding', 'harness racing', 'high jump', 'hockey', 'horse jumping', 'horse racing', 'horseshoe pitching', 'hurdles', 'hydroplane racing', 'ice climbing', 'ice yachting', 'jai alai', 'javelin', 'jousting', 'judo', 'lacrosse', 'log rolling', 'luge', 'motorcycle racing', 'mushing', 'nascar racing', 'olympic wrestling', 'parallel bar', 'pole climbing', 'pole dancing', 'pole vault', 'polo', 'pommel horse', 'rings', 'rock climbing', 'roller derby', 'rollerblade racing', 'rowing', 'rugby', 'sailboat racing', 'shot put', 'shuffleboard', 'sidecar racing', 'ski jumping', 'sky surfing', 'skydiving', 'snow boarding', 'snowmobile racing', 'speed skating', 'steer wrestling', 'sumo wrestling', 'surfing', 'swimming', 'table tennis', 'tennis', 'track bicycle', 'trapeze', 'tug of war', 'ultimate', 'uneven bars', 'volleyball', 'water cycling', 'water polo', 'weightlifting', 'wheelchair basketball', 'wheelchair racing', 'wingsuit flying']
# Test classes: ['air hockey', 'ampute football', 'archery', 'arm wrestling', 'axe throwing', 'balance beam', 'barell racing', 'baseball', 'basketball', 'baton twirling', 'bike polo', 'billiards', 'bmx', 'bobsled', 'bowling', 'boxing', 'bull riding', 'bungee jumping', 'canoe slamon', 'cheerleading', 'chuckwagon racing', 'cricket', 'croquet', 'curling', 'disc golf', 'fencing', 'field hockey', 'figure skating men', 'figure skating pairs', 'figure skating women', 'fly fishing', 'football', 'formula 1 racing', 'frisbee', 'gaga', 'giant slalom', 'golf', 'hammer throw', 'hang gliding', 'harness racing', 'high jump', 'hockey', 'horse jumping', 'horse racing', 'horseshoe pitching', 'hurdles', 'hydroplane racing', 'ice climbing', 'ice yachting', 'jai alai', 'javelin', 'jousting', 'judo', 'lacrosse', 'log rolling', 'luge', 'motorcycle racing', 'mushing', 'nascar racing', 'olympic wrestling', 'parallel bar', 'pole climbing', 'pole dancing', 'pole vault', 'polo', 'pommel horse', 'rings', 'rock climbing', 'roller derby', 'rollerblade racing', 'rowing', 'rugby', 'sailboat racing', 'shot put', 'shuffleboard', 'sidecar racing', 'ski jumping', 'sky surfing', 'skydiving', 'snow boarding', 'snowmobile racing', 'speed skating', 'steer wrestling', 'sumo wrestling', 'surfing', 'swimming', 'table tennis', 'tennis', 'track bicycle', 'trapeze', 'tug of war', 'ultimate', 'uneven bars', 'volleyball', 'water cycling', 'water polo', 'weightlifting', 'wheelchair basketball', 'wheelchair racing', 'wingsuit flying']

# %%
mode = "hog"
best_overall = None  # (test_f1, info_dict)

all_results = {}
cms = {}

#modes = ["hog", "lbp", "hog+lbp"]

for setting in pre_pca_grid:
    cfg.use_preprocess = setting["use_preprocess"]
    cfg.use_pca = setting["use_pca"]

    print("\n############################################")
    print("SETTING:", setting["tag"], "| preprocess:", cfg.use_preprocess, "| pca:", cfg.use_pca)
    print("############################################")

    for hg in hog_grid:
        cfg.hog_orientations = hg["hog_orientations"]
        cfg.hog_pixels_per_cell = hg["hog_pixels_per_cell"]
        cfg.hog_cells_per_block = hg["hog_cells_per_block"]
        cfg.hog_transform_sqrt = hg["hog_transform_sqrt"]
    
        print("\n====================")
        print("HOG CONFIG:", hg)
        print("====================")
    
        X_fit, y_fit   = get_or_build_xy(fit_ds,  cfg, mode, split_name="fit")
        X_test, y_test = get_or_build_xy(test_ds, cfg, mode, split_name="test")
    
        use_pca_now = cfg.use_pca

        max_n = min(X_fit.shape[0] - 1, X_fit.shape[1])
        pca_list = [n for n in cfg.pca_components_grid if n <= max_n and n >= 10]
        
        if use_pca_now and (len(pca_list) == 0):
            print(f"[WARN] Nessun n_components valido per PCA (max {max_n}). Disabilito PCA solo per questo giro.")
            use_pca_now = False
            pca_list = []

    
        models = get_models(cfg, pca_list if pca_list else [None], use_pca_now)
    
        for model_name, (pipe, grid) in models.items():
            if (not use_pca_now) and ("pca__n_components" in grid):
                grid = {k: v for k, v in grid.items() if k != "pca__n_components"}
    
            best_params, best_val_f1, test_acc, test_f1, cm, _ = tune_and_test_model(
                X_fit, y_fit, X_test, y_test, cfg, model_name, pipe, grid
            )
    
            print(f"\n--- {model_name} ---")
            print("Best params:", best_params)
            print(f"Val Macro-F1: {best_val_f1:.4f}")
            print(f"TEST Acc:     {test_acc:.4f}")
            print(f"TEST Macro-F1:{test_f1:.4f}")
    
            key = (setting["tag"], str(hg), model_name)
            all_results[key] = (best_params, best_val_f1, test_acc, test_f1)
            cms[key] = cm

    
            # salvaggio best overall 
            info = {
                "tag": setting["tag"],
                "hog": hg,
                "model": model_name,
                "best_params": best_params,
                "val_f1": best_val_f1,
                "test_acc": test_acc,
                "test_f1": test_f1
            }

            if (best_overall is None) or (test_f1 > best_overall[0]):
                best_overall = (test_f1, info)

print("\n=== BEST OVERALL (by TEST Macro-F1) ===")
print(best_overall[1])
# Out:
# ############################################
# SETTING: PRE0_PCA0 | preprocess: False | pca: False
# ############################################
#
# ====================
# HOG CONFIG: {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE MISS] calcolo feature per fit hog...
# [CACHE SAVE] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc8x8_hogcb2x2_hogsqrt1.npz
# [CACHE MISS] calcolo feature per test hog...
# [CACHE SAVE] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc8x8_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1}
# Val Macro-F1: 0.1223
# TEST Acc:     0.1120
# TEST Macro-F1:0.1064
#
# --- LogReg ---
# Best params: {'clf__C': 0.3}
# Val Macro-F1: 0.1287
# TEST Acc:     0.1480
# TEST Macro-F1:0.1367
#
# ====================
# HOG CONFIG: {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE MISS] calcolo feature per fit hog...
# [CACHE SAVE] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc8x8_hogcb2x2_hogsqrt1.npz
# [CACHE MISS] calcolo feature per test hog...
# [CACHE SAVE] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc8x8_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1}
# Val Macro-F1: 0.1123
# TEST Acc:     0.1100
# TEST Macro-F1:0.1054
#
# --- LogReg ---
# Best params: {'clf__C': 1.0}
# Val Macro-F1: 0.1539
# TEST Acc:     0.1520
# TEST Macro-F1:0.1444
#
# ====================
# HOG CONFIG: {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE MISS] calcolo feature per fit hog...
# [CACHE SAVE] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb2x2_hogsqrt1.npz
# [CACHE MISS] calcolo feature per test hog...
# [CACHE SAVE] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1}
# Val Macro-F1: 0.0923
# TEST Acc:     0.0580
# TEST Macro-F1:0.0565
#
# --- LogReg ---
# Best params: {'clf__C': 3.0}
# Val Macro-F1: 0.1069
# TEST Acc:     0.1700
# TEST Macro-F1:0.1559
#
# ====================
# HOG CONFIG: {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE MISS] calcolo feature per fit hog...
# [CACHE SAVE] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc16x16_hogcb2x2_hogsqrt1.npz
# [CACHE MISS] calcolo feature per test hog...
# [CACHE SAVE] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc16x16_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1}
# Val Macro-F1: 0.0883
# TEST Acc:     0.0860
# TEST Macro-F1:0.0822
#
# --- LogReg ---
# Best params: {'clf__C': 0.1}
# Val Macro-F1: 0.1279
# TEST Acc:     0.1760
# TEST Macro-F1:0.1674
#
# ====================
# HOG CONFIG: {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True}
# ====================
# [CACHE MISS] calcolo feature per fit hog...
# [CACHE SAVE] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb3x3_hogsqrt1.npz
# [CACHE MISS] calcolo feature per test hog...
# [CACHE SAVE] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb3x3_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1}
# Val Macro-F1: 0.0517
# TEST Acc:     0.0660
# TEST Macro-F1:0.0634
#
# --- LogReg ---
# Best params: {'clf__C': 3.0}
# Val Macro-F1: 0.1297
# TEST Acc:     0.1660
# TEST Macro-F1:0.1453
#
# ############################################
# SETTING: PRE0_PCA1 | preprocess: False | pca: True
# ############################################
#
# ====================
# HOG CONFIG: {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE HIT] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc8x8_hogcb2x2_hogsqrt1.npz
# [CACHE HIT] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc8x8_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1, 'pca__n_components': 256}
# Val Macro-F1: 0.0647
# TEST Acc:     0.0880
# TEST Macro-F1:0.0832
#
# --- LogReg ---
# Best params: {'clf__C': 0.3, 'pca__n_components': 256}
# Val Macro-F1: 0.1275
# TEST Acc:     0.1400
# TEST Macro-F1:0.1315
#
# ====================
# HOG CONFIG: {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE HIT] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc8x8_hogcb2x2_hogsqrt1.npz
# [CACHE HIT] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc8x8_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1, 'pca__n_components': 256}
# Val Macro-F1: 0.0767
# TEST Acc:     0.0840
# TEST Macro-F1:0.0763
#
# --- LogReg ---
# Best params: {'clf__C': 3.0, 'pca__n_components': 256}
# Val Macro-F1: 0.1407
# TEST Acc:     0.1540
# TEST Macro-F1:0.1365
#
# ====================
# HOG CONFIG: {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE HIT] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb2x2_hogsqrt1.npz
# [CACHE HIT] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1, 'pca__n_components': 256}
# Val Macro-F1: 0.0500
# TEST Acc:     0.0740
# TEST Macro-F1:0.0662
#
# --- LogReg ---
# Best params: {'clf__C': 10.0, 'pca__n_components': 256}
# Val Macro-F1: 0.1002
# TEST Acc:     0.1680
# TEST Macro-F1:0.1567
#
# ====================
# HOG CONFIG: {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE HIT] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc16x16_hogcb2x2_hogsqrt1.npz
# [CACHE HIT] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc16x16_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 1.0, 'pca__n_components': 256}
# Val Macro-F1: 0.0750
# TEST Acc:     0.0800
# TEST Macro-F1:0.0753
#
# --- LogReg ---
# Best params: {'clf__C': 3.0, 'pca__n_components': 256}
# Val Macro-F1: 0.1395
# TEST Acc:     0.1680
# TEST Macro-F1:0.1567
#
# ====================
# HOG CONFIG: {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True}
# ====================
# [CACHE HIT] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb3x3_hogsqrt1.npz
# [CACHE HIT] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre0_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb3x3_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1, 'pca__n_components': 256}
# Val Macro-F1: 0.0367
# TEST Acc:     0.0840
# TEST Macro-F1:0.0745
#
# --- LogReg ---
# Best params: {'clf__C': 3.0, 'pca__n_components': 256}
# Val Macro-F1: 0.1300
# TEST Acc:     0.1580
# TEST Macro-F1:0.1449
#
# ############################################
# SETTING: PRE1_PCA0 | preprocess: True | pca: False
# ############################################
#
# ====================
# HOG CONFIG: {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE HIT] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc8x8_hogcb2x2_hogsqrt1.npz
# [CACHE HIT] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc8x8_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1}
# Val Macro-F1: 0.0673
# TEST Acc:     0.0980
# TEST Macro-F1:0.0916
#
# --- LogReg ---
# Best params: {'clf__C': 3.0}
# Val Macro-F1: 0.1182
# TEST Acc:     0.1520
# TEST Macro-F1:0.1378
#
# ====================
# HOG CONFIG: {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE HIT] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc8x8_hogcb2x2_hogsqrt1.npz
# [CACHE HIT] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc8x8_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1}
# Val Macro-F1: 0.0633
# TEST Acc:     0.0960
# TEST Macro-F1:0.0889
#
# --- LogReg ---
# Best params: {'clf__C': 0.1}
# Val Macro-F1: 0.1120
# TEST Acc:     0.1460
# TEST Macro-F1:0.1323
#
# ====================
# HOG CONFIG: {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE MISS] calcolo feature per fit hog...
# [CACHE SAVE] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb2x2_hogsqrt1.npz
# [CACHE MISS] calcolo feature per test hog...
# [CACHE SAVE] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1}
# Val Macro-F1: 0.0402
# TEST Acc:     0.0460
# TEST Macro-F1:0.0425
#
# --- LogReg ---
# Best params: {'clf__C': 0.3}
# Val Macro-F1: 0.1162
# TEST Acc:     0.1680
# TEST Macro-F1:0.1567
#
# ====================
# HOG CONFIG: {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE MISS] calcolo feature per fit hog...
# [CACHE SAVE] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc16x16_hogcb2x2_hogsqrt1.npz
# [CACHE MISS] calcolo feature per test hog...
# [CACHE SAVE] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc16x16_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1}
# Val Macro-F1: 0.0500
# TEST Acc:     0.0500
# TEST Macro-F1:0.0449
#
# --- LogReg ---
# Best params: {'clf__C': 0.3}
# Val Macro-F1: 0.1167
# TEST Acc:     0.1640
# TEST Macro-F1:0.1495
#
# ====================
# HOG CONFIG: {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True}
# ====================
# [CACHE MISS] calcolo feature per fit hog...
# [CACHE SAVE] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb3x3_hogsqrt1.npz
# [CACHE MISS] calcolo feature per test hog...
# [CACHE SAVE] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb3x3_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1}
# Val Macro-F1: 0.0567
# TEST Acc:     0.0620
# TEST Macro-F1:0.0578
#
# --- LogReg ---
# Best params: {'clf__C': 3.0}
# Val Macro-F1: 0.1147
# TEST Acc:     0.1820
# TEST Macro-F1:0.1616
#
# ############################################
# SETTING: PRE1_PCA1 | preprocess: True | pca: True
# ############################################
#
# ====================
# HOG CONFIG: {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE HIT] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc8x8_hogcb2x2_hogsqrt1.npz
# [CACHE HIT] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc8x8_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.3, 'pca__n_components': 256}
# Val Macro-F1: 0.0652
# TEST Acc:     0.0760
# TEST Macro-F1:0.0662
#
# --- LogReg ---
# Best params: {'clf__C': 0.1, 'pca__n_components': 256}
# Val Macro-F1: 0.0993
# TEST Acc:     0.1440
# TEST Macro-F1:0.1284
#
# ====================
# HOG CONFIG: {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE HIT] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc8x8_hogcb2x2_hogsqrt1.npz
# [CACHE HIT] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc8x8_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1, 'pca__n_components': 256}
# Val Macro-F1: 0.0707
# TEST Acc:     0.0820
# TEST Macro-F1:0.0784
#
# --- LogReg ---
# Best params: {'clf__C': 3.0, 'pca__n_components': 256}
# Val Macro-F1: 0.1082
# TEST Acc:     0.1360
# TEST Macro-F1:0.1227
#
# ====================
# HOG CONFIG: {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE HIT] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb2x2_hogsqrt1.npz
# [CACHE HIT] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 1.0, 'pca__n_components': 256}
# Val Macro-F1: 0.0433
# TEST Acc:     0.0580
# TEST Macro-F1:0.0637
#
# --- LogReg ---
# Best params: {'clf__C': 10.0, 'pca__n_components': 256}
# Val Macro-F1: 0.1269
# TEST Acc:     0.1480
# TEST Macro-F1:0.1384
#
# ====================
# HOG CONFIG: {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}
# ====================
# [CACHE HIT] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc16x16_hogcb2x2_hogsqrt1.npz
# [CACHE HIT] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO12_hogpc16x16_hogcb2x2_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 0.1, 'pca__n_components': 256}
# Val Macro-F1: 0.0495
# TEST Acc:     0.1020
# TEST Macro-F1:0.1032
#
# --- LogReg ---
# Best params: {'clf__C': 3.0, 'pca__n_components': 256}
# Val Macro-F1: 0.1157
# TEST Acc:     0.1540
# TEST Macro-F1:0.1406
#
# ====================
# HOG CONFIG: {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True}
# ====================
# [CACHE HIT] fit hog -> /kaggle/working/feat_cache/Xy_fit_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb3x3_hogsqrt1.npz
# [CACHE HIT] test hog -> /kaggle/working/feat_cache/Xy_test_hog_img128_pre1_clahe1c0.01_den1sc0.05ss2_hogO9_hogpc16x16_hogcb3x3_hogsqrt1.npz
#
# --- LinearSVC ---
# Best params: {'clf__C': 10.0, 'pca__n_components': 256}
# Val Macro-F1: 0.0645
# TEST Acc:     0.0600
# TEST Macro-F1:0.0556
#
# --- LogReg ---
# Best params: {'clf__C': 3.0, 'pca__n_components': 256}
# Val Macro-F1: 0.1040
# TEST Acc:     0.1660
# TEST Macro-F1:0.1513
#
# === BEST OVERALL (by TEST Macro-F1) ===
# {'tag': 'PRE0_PCA0', 'hog': {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True}, 'model': 'LogReg', 'best_params': {'clf__C': 0.1}, 'val_f1': 0.12785714285714284, 'test_acc': 0.176, 'test_f1': 0.16737934451169745}

# %%
print("\n=== RIASSUNTO FINALE ===")
for (tag, hog_conf, model_name), (best_params, best_val_f1, test_acc, test_f1) in all_results.items():
    print(f"{tag} | {hog_conf} | {model_name:8} | ValF1={best_val_f1:.4f} | TestAcc={test_acc:.4f} | TestF1={test_f1:.4f} | {best_params}")
# Out:
# === RIASSUNTO FINALE ===
# PRE0_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.1223 | TestAcc=0.1120 | TestF1=0.1064 | {'clf__C': 0.1}
# PRE0_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1287 | TestAcc=0.1480 | TestF1=0.1367 | {'clf__C': 0.3}
# PRE0_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.1123 | TestAcc=0.1100 | TestF1=0.1054 | {'clf__C': 0.1}
# PRE0_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1539 | TestAcc=0.1520 | TestF1=0.1444 | {'clf__C': 1.0}
# PRE0_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0923 | TestAcc=0.0580 | TestF1=0.0565 | {'clf__C': 0.1}
# PRE0_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1069 | TestAcc=0.1700 | TestF1=0.1559 | {'clf__C': 3.0}
# PRE0_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0883 | TestAcc=0.0860 | TestF1=0.0822 | {'clf__C': 0.1}
# PRE0_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1279 | TestAcc=0.1760 | TestF1=0.1674 | {'clf__C': 0.1}
# PRE0_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0517 | TestAcc=0.0660 | TestF1=0.0634 | {'clf__C': 0.1}
# PRE0_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1297 | TestAcc=0.1660 | TestF1=0.1453 | {'clf__C': 3.0}
# PRE0_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0647 | TestAcc=0.0880 | TestF1=0.0832 | {'clf__C': 0.1, 'pca__n_components': 256}
# PRE0_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1275 | TestAcc=0.1400 | TestF1=0.1315 | {'clf__C': 0.3, 'pca__n_components': 256}
# PRE0_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0767 | TestAcc=0.0840 | TestF1=0.0763 | {'clf__C': 0.1, 'pca__n_components': 256}
# PRE0_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1407 | TestAcc=0.1540 | TestF1=0.1365 | {'clf__C': 3.0, 'pca__n_components': 256}
# PRE0_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0500 | TestAcc=0.0740 | TestF1=0.0662 | {'clf__C': 0.1, 'pca__n_components': 256}
# PRE0_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1002 | TestAcc=0.1680 | TestF1=0.1567 | {'clf__C': 10.0, 'pca__n_components': 256}
# PRE0_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0750 | TestAcc=0.0800 | TestF1=0.0753 | {'clf__C': 1.0, 'pca__n_components': 256}
# PRE0_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1395 | TestAcc=0.1680 | TestF1=0.1567 | {'clf__C': 3.0, 'pca__n_components': 256}
# PRE0_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0367 | TestAcc=0.0840 | TestF1=0.0745 | {'clf__C': 0.1, 'pca__n_components': 256}
# PRE0_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1300 | TestAcc=0.1580 | TestF1=0.1449 | {'clf__C': 3.0, 'pca__n_components': 256}
# PRE1_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0673 | TestAcc=0.0980 | TestF1=0.0916 | {'clf__C': 0.1}
# PRE1_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1182 | TestAcc=0.1520 | TestF1=0.1378 | {'clf__C': 3.0}
# PRE1_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0633 | TestAcc=0.0960 | TestF1=0.0889 | {'clf__C': 0.1}
# PRE1_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1120 | TestAcc=0.1460 | TestF1=0.1323 | {'clf__C': 0.1}
# PRE1_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0402 | TestAcc=0.0460 | TestF1=0.0425 | {'clf__C': 0.1}
# PRE1_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1162 | TestAcc=0.1680 | TestF1=0.1567 | {'clf__C': 0.3}
# PRE1_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0500 | TestAcc=0.0500 | TestF1=0.0449 | {'clf__C': 0.1}
# PRE1_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1167 | TestAcc=0.1640 | TestF1=0.1495 | {'clf__C': 0.3}
# PRE1_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0567 | TestAcc=0.0620 | TestF1=0.0578 | {'clf__C': 0.1}
# PRE1_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1147 | TestAcc=0.1820 | TestF1=0.1616 | {'clf__C': 3.0}
# PRE1_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0652 | TestAcc=0.0760 | TestF1=0.0662 | {'clf__C': 0.3, 'pca__n_components': 256}
# PRE1_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.0993 | TestAcc=0.1440 | TestF1=0.1284 | {'clf__C': 0.1, 'pca__n_components': 256}
# PRE1_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0707 | TestAcc=0.0820 | TestF1=0.0784 | {'clf__C': 0.1, 'pca__n_components': 256}
# PRE1_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1082 | TestAcc=0.1360 | TestF1=0.1227 | {'clf__C': 3.0, 'pca__n_components': 256}
# PRE1_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0433 | TestAcc=0.0580 | TestF1=0.0637 | {'clf__C': 1.0, 'pca__n_components': 256}
# PRE1_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1269 | TestAcc=0.1480 | TestF1=0.1384 | {'clf__C': 10.0, 'pca__n_components': 256}
# PRE1_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0495 | TestAcc=0.1020 | TestF1=0.1032 | {'clf__C': 0.1, 'pca__n_components': 256}
# PRE1_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1157 | TestAcc=0.1540 | TestF1=0.1406 | {'clf__C': 3.0, 'pca__n_components': 256}
# PRE1_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} | LinearSVC | ValF1=0.0645 | TestAcc=0.0600 | TestF1=0.0556 | {'clf__C': 10.0, 'pca__n_components': 256}
# PRE1_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} | LogReg   | ValF1=0.1040 | TestAcc=0.1660 | TestF1=0.1513 | {'clf__C': 3.0, 'pca__n_components': 256}

# %%
for (tag, hog_conf, model_name), cm in cms.items():
    print(f"\n=== Top confusions: {tag} | {hog_conf} + {model_name} ===")
    print_top_confusions(cm, class_names, top_k=30)
# Out:
# === Top confusions: PRE0_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# baton twirling → trapeze  | 2 errori
# disc golf → rings  | 2 errori
# figure skating men → figure skating pairs  | 2 errori
# hammer throw → hurdles  | 2 errori
# horse jumping → curling  | 2 errori
# olympic wrestling → curling  | 2 errori
# roller derby → cricket  | 2 errori
# sailboat racing → ice yachting  | 2 errori
# snow boarding → trapeze  | 2 errori
# sumo wrestling → horseshoe pitching  | 2 errori
# table tennis → trapeze  | 2 errori
# tennis → hang gliding  | 2 errori
# ultimate → bike polo  | 2 errori
# air hockey → bmx  | 1 errori
# air hockey → curling  | 1 errori
# air hockey → hockey  | 1 errori
# air hockey → nascar racing  | 1 errori
# ampute football → axe throwing  | 1 errori
# ampute football → olympic wrestling  | 1 errori
# ampute football → speed skating  | 1 errori
# ampute football → uneven bars  | 1 errori
# archery → log rolling  | 1 errori
# archery → olympic wrestling  | 1 errori
# archery → table tennis  | 1 errori
# archery → trapeze  | 1 errori
# arm wrestling → golf  | 1 errori
# arm wrestling → pommel horse  | 1 errori
# arm wrestling → shuffleboard  | 1 errori
# axe throwing → bowling  | 1 errori
# axe throwing → boxing  | 1 errori
#
# === Top confusions: PRE0_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# judo → trapeze  | 3 errori
# ampute football → sailboat racing  | 2 errori
# baton twirling → ice climbing  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# boxing → ice climbing  | 2 errori
# canoe slamon → rock climbing  | 2 errori
# cheerleading → disc golf  | 2 errori
# field hockey → bmx  | 2 errori
# figure skating men → trapeze  | 2 errori
# figure skating pairs → trapeze  | 2 errori
# giant slalom → trapeze  | 2 errori
# hang gliding → frisbee  | 2 errori
# hurdles → polo  | 2 errori
# hydroplane racing → canoe slamon  | 2 errori
# ice yachting → frisbee  | 2 errori
# rings → ice climbing  | 2 errori
# rock climbing → ice climbing  | 2 errori
# shot put → trapeze  | 2 errori
# sky surfing → figure skating men  | 2 errori
# skydiving → ice climbing  | 2 errori
# swimming → water polo  | 2 errori
# table tennis → trapeze  | 2 errori
# trapeze → balance beam  | 2 errori
# uneven bars → trapeze  | 2 errori
# water polo → rock climbing  | 2 errori
# air hockey → axe throwing  | 1 errori
# air hockey → ice climbing  | 1 errori
# air hockey → pommel horse  | 1 errori
# air hockey → skydiving  | 1 errori
# ampute football → figure skating women  | 1 errori
#
# === Top confusions: PRE0_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# axe throwing → gaga  | 2 errori
# baton twirling → trapeze  | 2 errori
# bobsled → sky surfing  | 2 errori
# field hockey → baton twirling  | 2 errori
# formula 1 racing → horse jumping  | 2 errori
# giant slalom → formula 1 racing  | 2 errori
# horse racing → gaga  | 2 errori
# javelin → archery  | 2 errori
# parallel bar → pommel horse  | 2 errori
# pole climbing → skydiving  | 2 errori
# rock climbing → ice climbing  | 2 errori
# sailboat racing → ice yachting  | 2 errori
# shot put → trapeze  | 2 errori
# snow boarding → trapeze  | 2 errori
# sumo wrestling → horseshoe pitching  | 2 errori
# table tennis → trapeze  | 2 errori
# tennis → arm wrestling  | 2 errori
# uneven bars → trapeze  | 2 errori
# water polo → mushing  | 2 errori
# wheelchair racing → speed skating  | 2 errori
# air hockey → hockey  | 1 errori
# air hockey → judo  | 1 errori
# air hockey → nascar racing  | 1 errori
# air hockey → pommel horse  | 1 errori
# air hockey → sailboat racing  | 1 errori
# ampute football → axe throwing  | 1 errori
# ampute football → olympic wrestling  | 1 errori
# ampute football → speed skating  | 1 errori
# ampute football → uneven bars  | 1 errori
# archery → balance beam  | 1 errori
#
# === Top confusions: PRE0_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# judo → trapeze  | 3 errori
# shot put → trapeze  | 3 errori
# ampute football → sailboat racing  | 2 errori
# arm wrestling → rowing  | 2 errori
# baton twirling → ice climbing  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# boxing → ice climbing  | 2 errori
# canoe slamon → rock climbing  | 2 errori
# cheerleading → disc golf  | 2 errori
# chuckwagon racing → hammer throw  | 2 errori
# figure skating men → trapeze  | 2 errori
# figure skating pairs → trapeze  | 2 errori
# formula 1 racing → sky surfing  | 2 errori
# giant slalom → trapeze  | 2 errori
# hang gliding → frisbee  | 2 errori
# high jump → ice climbing  | 2 errori
# hydroplane racing → canoe slamon  | 2 errori
# log rolling → fly fishing  | 2 errori
# polo → ice climbing  | 2 errori
# rings → ice climbing  | 2 errori
# rock climbing → ice climbing  | 2 errori
# roller derby → chuckwagon racing  | 2 errori
# rugby → wheelchair racing  | 2 errori
# sky surfing → figure skating women  | 2 errori
# skydiving → ice climbing  | 2 errori
# swimming → water polo  | 2 errori
# table tennis → trapeze  | 2 errori
# tennis → rings  | 2 errori
# track bicycle → chuckwagon racing  | 2 errori
# tug of war → ice climbing  | 2 errori
#
# === Top confusions: PRE0_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# volleyball → harness racing  | 3 errori
# ampute football → fly fishing  | 2 errori
# axe throwing → harness racing  | 2 errori
# cheerleading → sumo wrestling  | 2 errori
# cricket → log rolling  | 2 errori
# disc golf → cheerleading  | 2 errori
# field hockey → polo  | 2 errori
# formula 1 racing → swimming  | 2 errori
# harness racing → mushing  | 2 errori
# luge → rock climbing  | 2 errori
# olympic wrestling → curling  | 2 errori
# pole vault → roller derby  | 2 errori
# sidecar racing → chuckwagon racing  | 2 errori
# sky surfing → football  | 2 errori
# sky surfing → sumo wrestling  | 2 errori
# skydiving → bull riding  | 2 errori
# track bicycle → chuckwagon racing  | 2 errori
# weightlifting → bungee jumping  | 2 errori
# wheelchair racing → rowing  | 2 errori
# air hockey → canoe slamon  | 1 errori
# air hockey → disc golf  | 1 errori
# air hockey → harness racing  | 1 errori
# air hockey → ski jumping  | 1 errori
# air hockey → sumo wrestling  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → weightlifting  | 1 errori
# ampute football → wheelchair racing  | 1 errori
# archery → axe throwing  | 1 errori
# archery → fly fishing  | 1 errori
# archery → log rolling  | 1 errori
#
# === Top confusions: PRE0_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# judo → trapeze  | 3 errori
# axe throwing → wingsuit flying  | 2 errori
# barell racing → axe throwing  | 2 errori
# baseball → archery  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# disc golf → sailboat racing  | 2 errori
# figure skating men → pole climbing  | 2 errori
# figure skating women → figure skating pairs  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# horse racing → cheerleading  | 2 errori
# ice climbing → disc golf  | 2 errori
# jousting → mushing  | 2 errori
# rock climbing → ice climbing  | 2 errori
# sailboat racing → ice yachting  | 2 errori
# speed skating → trapeze  | 2 errori
# surfing → giant slalom  | 2 errori
# tennis → rings  | 2 errori
# track bicycle → bmx  | 2 errori
# tug of war → cheerleading  | 2 errori
# tug of war → disc golf  | 2 errori
# uneven bars → trapeze  | 2 errori
# air hockey → axe throwing  | 1 errori
# air hockey → cricket  | 1 errori
# air hockey → nascar racing  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → basketball  | 1 errori
# ampute football → fly fishing  | 1 errori
# ampute football → sailboat racing  | 1 errori
# ampute football → trapeze  | 1 errori
#
# === Top confusions: PRE0_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# balance beam → cricket  | 2 errori
# field hockey → bike polo  | 2 errori
# horse racing → harness racing  | 2 errori
# horseshoe pitching → wheelchair racing  | 2 errori
# motorcycle racing → sky surfing  | 2 errori
# nascar racing → gaga  | 2 errori
# rings → volleyball  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rugby → snowmobile racing  | 2 errori
# steer wrestling → ultimate  | 2 errori
# tug of war → wheelchair racing  | 2 errori
# water cycling → fly fishing  | 2 errori
# weightlifting → hammer throw  | 2 errori
# wheelchair basketball → disc golf  | 2 errori
# air hockey → hammer throw  | 1 errori
# air hockey → nascar racing  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → snowmobile racing  | 1 errori
# ampute football → fly fishing  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → weightlifting  | 1 errori
# ampute football → wheelchair racing  | 1 errori
# archery → axe throwing  | 1 errori
# archery → cricket  | 1 errori
# archery → frisbee  | 1 errori
# archery → log rolling  | 1 errori
# archery → pommel horse  | 1 errori
# arm wrestling → pommel horse  | 1 errori
# arm wrestling → rowing  | 1 errori
# arm wrestling → sumo wrestling  | 1 errori
#
# === Top confusions: PRE0_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# barell racing → axe throwing  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# canoe slamon → bmx  | 2 errori
# curling → field hockey  | 2 errori
# fly fishing → rowing  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# hockey → bull riding  | 2 errori
# jousting → mushing  | 2 errori
# judo → trapeze  | 2 errori
# log rolling → fly fishing  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rowing → swimming  | 2 errori
# sidecar racing → bobsled  | 2 errori
# air hockey → bobsled  | 1 errori
# air hockey → hammer throw  | 1 errori
# air hockey → nascar racing  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → basketball  | 1 errori
# ampute football → speed skating  | 1 errori
# ampute football → swimming  | 1 errori
# archery → horse racing  | 1 errori
# archery → log rolling  | 1 errori
# arm wrestling → pommel horse  | 1 errori
# arm wrestling → rock climbing  | 1 errori
# arm wrestling → sailboat racing  | 1 errori
# arm wrestling → sumo wrestling  | 1 errori
# axe throwing → air hockey  | 1 errori
# axe throwing → basketball  | 1 errori
#
# === Top confusions: PRE0_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# air hockey → harness racing  | 2 errori
# cheerleading → chuckwagon racing  | 2 errori
# cricket → polo  | 2 errori
# field hockey → polo  | 2 errori
# frisbee → polo  | 2 errori
# horseshoe pitching → wheelchair racing  | 2 errori
# rock climbing → chuckwagon racing  | 2 errori
# sumo wrestling → horse jumping  | 2 errori
# tennis → rugby  | 2 errori
# track bicycle → snowmobile racing  | 2 errori
# ultimate → disc golf  | 2 errori
# volleyball → harness racing  | 2 errori
# air hockey → bmx  | 1 errori
# air hockey → canoe slamon  | 1 errori
# air hockey → sidecar racing  | 1 errori
# ampute football → fly fishing  | 1 errori
# ampute football → sidecar racing  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → swimming  | 1 errori
# archery → cricket  | 1 errori
# archery → harness racing  | 1 errori
# archery → rollerblade racing  | 1 errori
# archery → water polo  | 1 errori
# arm wrestling → pommel horse  | 1 errori
# arm wrestling → rock climbing  | 1 errori
# arm wrestling → snowmobile racing  | 1 errori
# arm wrestling → water cycling  | 1 errori
# axe throwing → bull riding  | 1 errori
# axe throwing → bungee jumping  | 1 errori
# axe throwing → figure skating women  | 1 errori
#
# === Top confusions: PRE0_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# canoe slamon → bmx  | 3 errori
# weightlifting → trapeze  | 3 errori
# barell racing → axe throwing  | 2 errori
# figure skating men → bowling  | 2 errori
# figure skating men → pole climbing  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# horse racing → roller derby  | 2 errori
# judo → trapeze  | 2 errori
# olympic wrestling → field hockey  | 2 errori
# pole climbing → trapeze  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rowing → swimming  | 2 errori
# rugby → roller derby  | 2 errori
# sailboat racing → ice yachting  | 2 errori
# swimming → rock climbing  | 2 errori
# uneven bars → trapeze  | 2 errori
# air hockey → axe throwing  | 1 errori
# air hockey → bobsled  | 1 errori
# air hockey → snowmobile racing  | 1 errori
# air hockey → sumo wrestling  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → basketball  | 1 errori
# ampute football → fly fishing  | 1 errori
# ampute football → swimming  | 1 errori
# ampute football → trapeze  | 1 errori
# archery → mushing  | 1 errori
# archery → rugby  | 1 errori
# arm wrestling → horseshoe pitching  | 1 errori
# arm wrestling → jai alai  | 1 errori
#
# === Top confusions: PRE0_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# canoe slamon → rock climbing  | 2 errori
# curling → harness racing  | 2 errori
# disc golf → croquet  | 2 errori
# hang gliding → rock climbing  | 2 errori
# horse jumping → hammer throw  | 2 errori
# log rolling → croquet  | 2 errori
# mushing → tug of war  | 2 errori
# polo → rock climbing  | 2 errori
# rings → ultimate  | 2 errori
# rock climbing → ice climbing  | 2 errori
# sumo wrestling → bmx  | 2 errori
# tug of war → horseshoe pitching  | 2 errori
# ultimate → canoe slamon  | 2 errori
# volleyball → football  | 2 errori
# water cycling → swimming  | 2 errori
# water polo → rock climbing  | 2 errori
# air hockey → fly fishing  | 1 errori
# air hockey → nascar racing  | 1 errori
# air hockey → pole climbing  | 1 errori
# ampute football → axe throwing  | 1 errori
# ampute football → fly fishing  | 1 errori
# ampute football → sailboat racing  | 1 errori
# ampute football → snowmobile racing  | 1 errori
# archery → log rolling  | 1 errori
# archery → steer wrestling  | 1 errori
# archery → trapeze  | 1 errori
# arm wrestling → luge  | 1 errori
# arm wrestling → pommel horse  | 1 errori
# arm wrestling → rowing  | 1 errori
# arm wrestling → shuffleboard  | 1 errori
#
# === Top confusions: PRE0_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# roller derby → chuckwagon racing  | 4 errori
# shot put → trapeze  | 3 errori
# ampute football → sailboat racing  | 2 errori
# ampute football → wheelchair racing  | 2 errori
# axe throwing → gaga  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# boxing → snowmobile racing  | 2 errori
# cheerleading → disc golf  | 2 errori
# chuckwagon racing → hammer throw  | 2 errori
# figure skating men → trapeze  | 2 errori
# figure skating pairs → trapeze  | 2 errori
# figure skating women → ice yachting  | 2 errori
# giant slalom → trapeze  | 2 errori
# hammer throw → sailboat racing  | 2 errori
# high jump → ice climbing  | 2 errori
# hurdles → polo  | 2 errori
# hydroplane racing → canoe slamon  | 2 errori
# ice yachting → frisbee  | 2 errori
# judo → trapeze  | 2 errori
# rock climbing → ice climbing  | 2 errori
# swimming → rowing  | 2 errori
# trapeze → balance beam  | 2 errori
# uneven bars → trapeze  | 2 errori
# water polo → rock climbing  | 2 errori
# water polo → swimming  | 2 errori
# wheelchair racing → rock climbing  | 2 errori
# air hockey → axe throwing  | 1 errori
# air hockey → pommel horse  | 1 errori
# air hockey → trapeze  | 1 errori
# ampute football → frisbee  | 1 errori
#
# === Top confusions: PRE0_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# bike polo → ampute football  | 2 errori
# bobsled → fly fishing  | 2 errori
# chuckwagon racing → mushing  | 2 errori
# figure skating women → frisbee  | 2 errori
# fly fishing → barell racing  | 2 errori
# horseshoe pitching → rollerblade racing  | 2 errori
# judo → trapeze  | 2 errori
# rock climbing → ice climbing  | 2 errori
# speed skating → sky surfing  | 2 errori
# tug of war → disc golf  | 2 errori
# air hockey → horse racing  | 1 errori
# air hockey → ice climbing  | 1 errori
# air hockey → nascar racing  | 1 errori
# air hockey → sailboat racing  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → basketball  | 1 errori
# ampute football → horse jumping  | 1 errori
# ampute football → ice yachting  | 1 errori
# ampute football → water polo  | 1 errori
# archery → log rolling  | 1 errori
# archery → rugby  | 1 errori
# archery → steer wrestling  | 1 errori
# arm wrestling → axe throwing  | 1 errori
# arm wrestling → croquet  | 1 errori
# arm wrestling → pommel horse  | 1 errori
# arm wrestling → rowing  | 1 errori
# axe throwing → air hockey  | 1 errori
# axe throwing → barell racing  | 1 errori
# axe throwing → billiards  | 1 errori
# axe throwing → bull riding  | 1 errori
#
# === Top confusions: PRE0_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# shot put → trapeze  | 3 errori
# ampute football → sailboat racing  | 2 errori
# axe throwing → gaga  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# figure skating men → trapeze  | 2 errori
# figure skating pairs → trapeze  | 2 errori
# giant slalom → trapeze  | 2 errori
# hammer throw → sailboat racing  | 2 errori
# hang gliding → frisbee  | 2 errori
# ice yachting → frisbee  | 2 errori
# judo → trapeze  | 2 errori
# log rolling → fly fishing  | 2 errori
# rock climbing → ice climbing  | 2 errori
# roller derby → chuckwagon racing  | 2 errori
# shuffleboard → golf  | 2 errori
# ski jumping → trapeze  | 2 errori
# snow boarding → trapeze  | 2 errori
# tug of war → disc golf  | 2 errori
# ultimate → disc golf  | 2 errori
# uneven bars → trapeze  | 2 errori
# water polo → rock climbing  | 2 errori
# air hockey → ice climbing  | 1 errori
# air hockey → pommel horse  | 1 errori
# ampute football → lacrosse  | 1 errori
# ampute football → uneven bars  | 1 errori
# ampute football → wheelchair racing  | 1 errori
# archery → baseball  | 1 errori
# archery → golf  | 1 errori
# archery → log rolling  | 1 errori
# archery → uneven bars  | 1 errori
#
# === Top confusions: PRE0_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# pole climbing → bobsled  | 3 errori
# baseball → mushing  | 2 errori
# bull riding → horse racing  | 2 errori
# horse jumping → snowmobile racing  | 2 errori
# judo → hurdles  | 2 errori
# roller derby → chuckwagon racing  | 2 errori
# rugby → snowmobile racing  | 2 errori
# sailboat racing → water polo  | 2 errori
# wingsuit flying → barell racing  | 2 errori
# air hockey → ampute football  | 1 errori
# air hockey → canoe slamon  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → tug of war  | 1 errori
# air hockey → water polo  | 1 errori
# ampute football → chuckwagon racing  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → ultimate  | 1 errori
# archery → axe throwing  | 1 errori
# archery → fencing  | 1 errori
# archery → log rolling  | 1 errori
# archery → water cycling  | 1 errori
# arm wrestling → ampute football  | 1 errori
# arm wrestling → bobsled  | 1 errori
# arm wrestling → horse jumping  | 1 errori
# arm wrestling → pommel horse  | 1 errori
# axe throwing → air hockey  | 1 errori
# axe throwing → bmx  | 1 errori
# axe throwing → cricket  | 1 errori
# axe throwing → ice climbing  | 1 errori
# axe throwing → tennis  | 1 errori
#
# === Top confusions: PRE0_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# judo → trapeze  | 3 errori
# arm wrestling → sailboat racing  | 2 errori
# axe throwing → wingsuit flying  | 2 errori
# barell racing → axe throwing  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# cheerleading → mushing  | 2 errori
# figure skating men → pole climbing  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# hammer throw → disc golf  | 2 errori
# horse racing → cheerleading  | 2 errori
# horseshoe pitching → golf  | 2 errori
# jousting → mushing  | 2 errori
# log rolling → disc golf  | 2 errori
# rock climbing → ice climbing  | 2 errori
# tug of war → disc golf  | 2 errori
# air hockey → axe throwing  | 1 errori
# air hockey → field hockey  | 1 errori
# air hockey → hammer throw  | 1 errori
# air hockey → nascar racing  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → basketball  | 1 errori
# ampute football → disc golf  | 1 errori
# ampute football → sailboat racing  | 1 errori
# ampute football → trapeze  | 1 errori
# archery → air hockey  | 1 errori
# archery → fencing  | 1 errori
# archery → log rolling  | 1 errori
# arm wrestling → jai alai  | 1 errori
# arm wrestling → rock climbing  | 1 errori
#
# === Top confusions: PRE0_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# baseball → javelin  | 2 errori
# curling → bmx  | 2 errori
# formula 1 racing → nascar racing  | 2 errori
# hang gliding → rock climbing  | 2 errori
# hockey → bull riding  | 2 errori
# horse jumping → curling  | 2 errori
# horse racing → chuckwagon racing  | 2 errori
# horseshoe pitching → wheelchair racing  | 2 errori
# ice climbing → horse jumping  | 2 errori
# judo → hurdles  | 2 errori
# lacrosse → wheelchair racing  | 2 errori
# trapeze → cheerleading  | 2 errori
# wingsuit flying → high jump  | 2 errori
# air hockey → bmx  | 1 errori
# air hockey → horse racing  | 1 errori
# air hockey → hurdles  | 1 errori
# air hockey → lacrosse  | 1 errori
# air hockey → ultimate  | 1 errori
# ampute football → bull riding  | 1 errori
# ampute football → sidecar racing  | 1 errori
# ampute football → speed skating  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → swimming  | 1 errori
# archery → bike polo  | 1 errori
# archery → cheerleading  | 1 errori
# archery → giant slalom  | 1 errori
# archery → rock climbing  | 1 errori
# archery → water cycling  | 1 errori
# arm wrestling → barell racing  | 1 errori
# arm wrestling → bull riding  | 1 errori
#
# === Top confusions: PRE0_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# tug of war → disc golf  | 3 errori
# axe throwing → air hockey  | 2 errori
# baseball → javelin  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# canoe slamon → chuckwagon racing  | 2 errori
# chuckwagon racing → sumo wrestling  | 2 errori
# curling → field hockey  | 2 errori
# fly fishing → rowing  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# hammer throw → sailboat racing  | 2 errori
# hockey → bull riding  | 2 errori
# horse racing → cheerleading  | 2 errori
# jousting → mushing  | 2 errori
# judo → trapeze  | 2 errori
# mushing → roller derby  | 2 errori
# pommel horse → tennis  | 2 errori
# rock climbing → ice climbing  | 2 errori
# swimming → rock climbing  | 2 errori
# volleyball → cheerleading  | 2 errori
# air hockey → bobsled  | 1 errori
# air hockey → hammer throw  | 1 errori
# air hockey → nascar racing  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → basketball  | 1 errori
# ampute football → fly fishing  | 1 errori
# ampute football → speed skating  | 1 errori
# ampute football → swimming  | 1 errori
# archery → horse racing  | 1 errori
#
# === Top confusions: PRE0_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# balance beam → wingsuit flying  | 2 errori
# boxing → disc golf  | 2 errori
# cheerleading → roller derby  | 2 errori
# chuckwagon racing → ampute football  | 2 errori
# disc golf → swimming  | 2 errori
# horseshoe pitching → wheelchair racing  | 2 errori
# ice climbing → horse jumping  | 2 errori
# jai alai → rowing  | 2 errori
# nascar racing → luge  | 2 errori
# rings → horse racing  | 2 errori
# sky surfing → rock climbing  | 2 errori
# tennis → judo  | 2 errori
# trapeze → balance beam  | 2 errori
# weightlifting → water polo  | 2 errori
# wheelchair basketball → rowing  | 2 errori
# wheelchair racing → motorcycle racing  | 2 errori
# wheelchair racing → mushing  | 2 errori
# air hockey → nascar racing  | 1 errori
# air hockey → polo  | 1 errori
# air hockey → snowmobile racing  | 1 errori
# air hockey → surfing  | 1 errori
# air hockey → trapeze  | 1 errori
# ampute football → chuckwagon racing  | 1 errori
# ampute football → snowmobile racing  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → ultimate  | 1 errori
# ampute football → wheelchair basketball  | 1 errori
# archery → boxing  | 1 errori
# archery → log rolling  | 1 errori
# archery → roller derby  | 1 errori
#
# === Top confusions: PRE0_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# canoe slamon → bmx  | 3 errori
# basketball → cheerleading  | 2 errori
# boxing → disc golf  | 2 errori
# cheerleading → mushing  | 2 errori
# figure skating men → bowling  | 2 errori
# formula 1 racing → swimming  | 2 errori
# horse racing → roller derby  | 2 errori
# judo → trapeze  | 2 errori
# pole climbing → trapeze  | 2 errori
# pole vault → track bicycle  | 2 errori
# rings → sumo wrestling  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rowing → swimming  | 2 errori
# swimming → rock climbing  | 2 errori
# weightlifting → trapeze  | 2 errori
# air hockey → nascar racing  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → snowmobile racing  | 1 errori
# air hockey → sumo wrestling  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → basketball  | 1 errori
# ampute football → disc golf  | 1 errori
# ampute football → swimming  | 1 errori
# ampute football → trapeze  | 1 errori
# archery → log rolling  | 1 errori
# archery → rugby  | 1 errori
# archery → table tennis  | 1 errori
# arm wrestling → horseshoe pitching  | 1 errori
# arm wrestling → jai alai  | 1 errori
#
# === Top confusions: PRE1_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# air hockey → axe throwing  | 2 errori
# bike polo → weightlifting  | 2 errori
# cricket → log rolling  | 2 errori
# figure skating men → figure skating pairs  | 2 errori
# figure skating pairs → trapeze  | 2 errori
# high jump → volleyball  | 2 errori
# javelin → hammer throw  | 2 errori
# jousting → boxing  | 2 errori
# olympic wrestling → pole vault  | 2 errori
# pommel horse → ice yachting  | 2 errori
# rock climbing → ice climbing  | 2 errori
# sidecar racing → trapeze  | 2 errori
# ski jumping → pole vault  | 2 errori
# uneven bars → trapeze  | 2 errori
# air hockey → archery  | 1 errori
# air hockey → pole vault  | 1 errori
# air hockey → trapeze  | 1 errori
# ampute football → axe throwing  | 1 errori
# ampute football → disc golf  | 1 errori
# ampute football → figure skating men  | 1 errori
# ampute football → luge  | 1 errori
# ampute football → speed skating  | 1 errori
# archery → boxing  | 1 errori
# archery → curling  | 1 errori
# archery → trapeze  | 1 errori
# arm wrestling → pole vault  | 1 errori
# arm wrestling → snow boarding  | 1 errori
# arm wrestling → trapeze  | 1 errori
# axe throwing → canoe slamon  | 1 errori
# axe throwing → gaga  | 1 errori
#
# === Top confusions: PRE1_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# bungee jumping → rock climbing  | 3 errori
# table tennis → trapeze  | 3 errori
# arm wrestling → rowing  | 2 errori
# axe throwing → gaga  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# cheerleading → disc golf  | 2 errori
# field hockey → roller derby  | 2 errori
# figure skating men → trapeze  | 2 errori
# figure skating pairs → trapeze  | 2 errori
# high jump → rock climbing  | 2 errori
# horse jumping → jousting  | 2 errori
# javelin → snowmobile racing  | 2 errori
# judo → trapeze  | 2 errori
# lacrosse → roller derby  | 2 errori
# lacrosse → wheelchair racing  | 2 errori
# log rolling → rock climbing  | 2 errori
# rock climbing → ice climbing  | 2 errori
# roller derby → chuckwagon racing  | 2 errori
# shot put → uneven bars  | 2 errori
# steer wrestling → golf  | 2 errori
# sumo wrestling → tennis  | 2 errori
# tug of war → disc golf  | 2 errori
# ultimate → disc golf  | 2 errori
# uneven bars → trapeze  | 2 errori
# air hockey → archery  | 1 errori
# air hockey → pole vault  | 1 errori
# air hockey → pommel horse  | 1 errori
# air hockey → trapeze  | 1 errori
# ampute football → bobsled  | 1 errori
# ampute football → figure skating women  | 1 errori
#
# === Top confusions: PRE1_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# air hockey → pole vault  | 2 errori
# bungee jumping → fencing  | 2 errori
# bungee jumping → wheelchair racing  | 2 errori
# cricket → wheelchair racing  | 2 errori
# figure skating men → figure skating pairs  | 2 errori
# figure skating pairs → hang gliding  | 2 errori
# fly fishing → barell racing  | 2 errori
# formula 1 racing → swimming  | 2 errori
# hockey → judo  | 2 errori
# hydroplane racing → pole dancing  | 2 errori
# javelin → snowmobile racing  | 2 errori
# nascar racing → luge  | 2 errori
# rings → ice yachting  | 2 errori
# ski jumping → pole vault  | 2 errori
# steer wrestling → nascar racing  | 2 errori
# uneven bars → trapeze  | 2 errori
# wheelchair racing → speed skating  | 2 errori
# air hockey → axe throwing  | 1 errori
# air hockey → balance beam  | 1 errori
# air hockey → trapeze  | 1 errori
# ampute football → axe throwing  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → speed skating  | 1 errori
# ampute football → trapeze  | 1 errori
# ampute football → uneven bars  | 1 errori
# archery → high jump  | 1 errori
# archery → trapeze  | 1 errori
# arm wrestling → pole vault  | 1 errori
# arm wrestling → trapeze  | 1 errori
# arm wrestling → wheelchair basketball  | 1 errori
#
# === Top confusions: PRE1_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# table tennis → trapeze  | 3 errori
# ampute football → uneven bars  | 2 errori
# arm wrestling → rowing  | 2 errori
# axe throwing → gaga  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# bungee jumping → rock climbing  | 2 errori
# cheerleading → disc golf  | 2 errori
# figure skating men → trapeze  | 2 errori
# figure skating pairs → trapeze  | 2 errori
# formula 1 racing → sky surfing  | 2 errori
# giant slalom → trapeze  | 2 errori
# horse jumping → jousting  | 2 errori
# horse racing → roller derby  | 2 errori
# javelin → snowmobile racing  | 2 errori
# judo → trapeze  | 2 errori
# lacrosse → roller derby  | 2 errori
# lacrosse → wheelchair racing  | 2 errori
# rock climbing → ice climbing  | 2 errori
# roller derby → chuckwagon racing  | 2 errori
# shot put → uneven bars  | 2 errori
# sky surfing → figure skating women  | 2 errori
# sumo wrestling → tennis  | 2 errori
# tug of war → disc golf  | 2 errori
# uneven bars → trapeze  | 2 errori
# air hockey → ice climbing  | 1 errori
# air hockey → pole vault  | 1 errori
# air hockey → pommel horse  | 1 errori
# air hockey → snowmobile racing  | 1 errori
# air hockey → trapeze  | 1 errori
# ampute football → bobsled  | 1 errori
#
# === Top confusions: PRE1_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# harness racing → mushing  | 3 errori
# balance beam → fly fishing  | 2 errori
# bmx → rollerblade racing  | 2 errori
# canoe slamon → bmx  | 2 errori
# golf → horse jumping  | 2 errori
# horseshoe pitching → bungee jumping  | 2 errori
# ice climbing → horse jumping  | 2 errori
# judo → hurdles  | 2 errori
# motorcycle racing → wheelchair racing  | 2 errori
# shot put → ski jumping  | 2 errori
# sidecar racing → chuckwagon racing  | 2 errori
# swimming → rowing  | 2 errori
# wheelchair basketball → disc golf  | 2 errori
# air hockey → axe throwing  | 1 errori
# air hockey → field hockey  | 1 errori
# air hockey → rugby  | 1 errori
# air hockey → steer wrestling  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → ultimate  | 1 errori
# ampute football → weightlifting  | 1 errori
# ampute football → wheelchair racing  | 1 errori
# archery → ampute football  | 1 errori
# archery → bobsled  | 1 errori
# archery → cricket  | 1 errori
# archery → horse jumping  | 1 errori
# archery → rowing  | 1 errori
# arm wrestling → barell racing  | 1 errori
# arm wrestling → bungee jumping  | 1 errori
# arm wrestling → fly fishing  | 1 errori
# arm wrestling → lacrosse  | 1 errori
#
# === Top confusions: PRE1_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# barell racing → axe throwing  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# bungee jumping → rock climbing  | 2 errori
# fly fishing → rock climbing  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rowing → swimming  | 2 errori
# tennis → rings  | 2 errori
# air hockey → bobsled  | 1 errori
# air hockey → ski jumping  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → curling  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → swimming  | 1 errori
# archery → log rolling  | 1 errori
# archery → volleyball  | 1 errori
# arm wrestling → pommel horse  | 1 errori
# arm wrestling → shuffleboard  | 1 errori
# arm wrestling → sumo wrestling  | 1 errori
# arm wrestling → wheelchair basketball  | 1 errori
# axe throwing → air hockey  | 1 errori
# axe throwing → barell racing  | 1 errori
# axe throwing → basketball  | 1 errori
# axe throwing → bungee jumping  | 1 errori
# axe throwing → mushing  | 1 errori
# balance beam → baton twirling  | 1 errori
# balance beam → bungee jumping  | 1 errori
# balance beam → fencing  | 1 errori
# balance beam → uneven bars  | 1 errori
#
# === Top confusions: PRE1_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# air hockey → hurdles  | 2 errori
# boxing → fly fishing  | 2 errori
# chuckwagon racing → water polo  | 2 errori
# high jump → chuckwagon racing  | 2 errori
# jai alai → disc golf  | 2 errori
# lacrosse → wheelchair racing  | 2 errori
# pole climbing → skydiving  | 2 errori
# sky surfing → ultimate  | 2 errori
# sumo wrestling → snowmobile racing  | 2 errori
# surfing → water cycling  | 2 errori
# table tennis → javelin  | 2 errori
# water cycling → bike polo  | 2 errori
# water polo → snowmobile racing  | 2 errori
# wheelchair basketball → disc golf  | 2 errori
# air hockey → field hockey  | 1 errori
# air hockey → steer wrestling  | 1 errori
# air hockey → tennis  | 1 errori
# ampute football → bull riding  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → weightlifting  | 1 errori
# ampute football → wheelchair racing  | 1 errori
# archery → high jump  | 1 errori
# archery → horse racing  | 1 errori
# archery → rowing  | 1 errori
# archery → water cycling  | 1 errori
# archery → wheelchair racing  | 1 errori
# arm wrestling → barell racing  | 1 errori
# arm wrestling → lacrosse  | 1 errori
# arm wrestling → pommel horse  | 1 errori
# arm wrestling → sumo wrestling  | 1 errori
#
# === Top confusions: PRE1_PCA0 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# balance beam → baton twirling  | 2 errori
# baseball → javelin  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# bungee jumping → rock climbing  | 2 errori
# canoe slamon → bmx  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# formula 1 racing → swimming  | 2 errori
# hockey → bull riding  | 2 errori
# horse racing → wheelchair racing  | 2 errori
# horseshoe pitching → wheelchair racing  | 2 errori
# hurdles → wheelchair racing  | 2 errori
# judo → trapeze  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rowing → swimming  | 2 errori
# rugby → chuckwagon racing  | 2 errori
# swimming → rock climbing  | 2 errori
# tennis → rings  | 2 errori
# tug of war → cheerleading  | 2 errori
# uneven bars → trapeze  | 2 errori
# air hockey → bobsled  | 1 errori
# air hockey → horse jumping  | 1 errori
# air hockey → luge  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → curling  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → swimming  | 1 errori
# archery → log rolling  | 1 errori
# archery → volleyball  | 1 errori
# arm wrestling → barell racing  | 1 errori
#
# === Top confusions: PRE1_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# lacrosse → wheelchair racing  | 3 errori
# arm wrestling → chuckwagon racing  | 2 errori
# axe throwing → high jump  | 2 errori
# cricket → steer wrestling  | 2 errori
# figure skating women → fly fishing  | 2 errori
# frisbee → chuckwagon racing  | 2 errori
# gaga → chuckwagon racing  | 2 errori
# hockey → cricket  | 2 errori
# horseshoe pitching → bungee jumping  | 2 errori
# rings → rock climbing  | 2 errori
# rowing → harness racing  | 2 errori
# rugby → motorcycle racing  | 2 errori
# steer wrestling → roller derby  | 2 errori
# surfing → horseshoe pitching  | 2 errori
# table tennis → cheerleading  | 2 errori
# tennis → golf  | 2 errori
# track bicycle → giant slalom  | 2 errori
# track bicycle → horse racing  | 2 errori
# tug of war → bowling  | 2 errori
# air hockey → bobsled  | 1 errori
# air hockey → lacrosse  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → speed skating  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → mushing  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → wheelchair racing  | 1 errori
# archery → harness racing  | 1 errori
# archery → polo  | 1 errori
# archery → rollerblade racing  | 1 errori
#
# === Top confusions: PRE1_PCA0 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# weightlifting → trapeze  | 3 errori
# barell racing → axe throwing  | 2 errori
# bungee jumping → rock climbing  | 2 errori
# canoe slamon → bmx  | 2 errori
# disc golf → croquet  | 2 errori
# figure skating men → bowling  | 2 errori
# figure skating men → pole climbing  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# horse racing → roller derby  | 2 errori
# judo → trapeze  | 2 errori
# olympic wrestling → field hockey  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rowing → swimming  | 2 errori
# rugby → chuckwagon racing  | 2 errori
# ski jumping → arm wrestling  | 2 errori
# swimming → fly fishing  | 2 errori
# uneven bars → trapeze  | 2 errori
# air hockey → luge  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → trapeze  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → basketball  | 1 errori
# ampute football → field hockey  | 1 errori
# ampute football → swimming  | 1 errori
# ampute football → trapeze  | 1 errori
# archery → billiards  | 1 errori
# archery → rugby  | 1 errori
# arm wrestling → barell racing  | 1 errori
# arm wrestling → horseshoe pitching  | 1 errori
#
# === Top confusions: PRE1_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# air hockey → pommel horse  | 2 errori
# basketball → rock climbing  | 2 errori
# canoe slamon → snowmobile racing  | 2 errori
# figure skating women → fly fishing  | 2 errori
# fly fishing → hammer throw  | 2 errori
# frisbee → mushing  | 2 errori
# golf → chuckwagon racing  | 2 errori
# luge → rock climbing  | 2 errori
# sumo wrestling → tennis  | 2 errori
# water cycling → wheelchair basketball  | 2 errori
# wingsuit flying → surfing  | 2 errori
# air hockey → giant slalom  | 1 errori
# air hockey → rollerblade racing  | 1 errori
# air hockey → sailboat racing  | 1 errori
# ampute football → hammer throw  | 1 errori
# ampute football → horse jumping  | 1 errori
# ampute football → motorcycle racing  | 1 errori
# ampute football → sailboat racing  | 1 errori
# ampute football → uneven bars  | 1 errori
# archery → field hockey  | 1 errori
# archery → volleyball  | 1 errori
# arm wrestling → pommel horse  | 1 errori
# arm wrestling → rowing  | 1 errori
# arm wrestling → sailboat racing  | 1 errori
# arm wrestling → shuffleboard  | 1 errori
# arm wrestling → surfing  | 1 errori
# axe throwing → air hockey  | 1 errori
# axe throwing → fencing  | 1 errori
# axe throwing → giant slalom  | 1 errori
# axe throwing → hydroplane racing  | 1 errori
#
# === Top confusions: PRE1_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# bungee jumping → rock climbing  | 3 errori
# ampute football → wheelchair racing  | 2 errori
# baton twirling → ski jumping  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# figure skating pairs → trapeze  | 2 errori
# figure skating women → figure skating men  | 2 errori
# judo → trapeze  | 2 errori
# lacrosse → wheelchair racing  | 2 errori
# luge → rock climbing  | 2 errori
# olympic wrestling → field hockey  | 2 errori
# rock climbing → disc golf  | 2 errori
# roller derby → disc golf  | 2 errori
# shot put → uneven bars  | 2 errori
# surfing → ultimate  | 2 errori
# uneven bars → trapeze  | 2 errori
# water polo → swimming  | 2 errori
# air hockey → archery  | 1 errori
# air hockey → pole vault  | 1 errori
# air hockey → pommel horse  | 1 errori
# air hockey → trapeze  | 1 errori
# ampute football → fly fishing  | 1 errori
# ampute football → sailboat racing  | 1 errori
# ampute football → swimming  | 1 errori
# archery → volleyball  | 1 errori
# arm wrestling → rowing  | 1 errori
# arm wrestling → shuffleboard  | 1 errori
# arm wrestling → surfing  | 1 errori
# arm wrestling → trapeze  | 1 errori
# axe throwing → air hockey  | 1 errori
# axe throwing → fencing  | 1 errori
#
# === Top confusions: PRE1_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# disc golf → ski jumping  | 2 errori
# football → bungee jumping  | 2 errori
# formula 1 racing → nascar racing  | 2 errori
# hang gliding → formula 1 racing  | 2 errori
# hockey → ultimate  | 2 errori
# rock climbing → ice climbing  | 2 errori
# ultimate → disc golf  | 2 errori
# uneven bars → trapeze  | 2 errori
# air hockey → ampute football  | 1 errori
# air hockey → balance beam  | 1 errori
# air hockey → luge  | 1 errori
# air hockey → pole vault  | 1 errori
# air hockey → snowmobile racing  | 1 errori
# ampute football → cheerleading  | 1 errori
# ampute football → field hockey  | 1 errori
# ampute football → fly fishing  | 1 errori
# ampute football → olympic wrestling  | 1 errori
# archery → disc golf  | 1 errori
# archery → harness racing  | 1 errori
# archery → ultimate  | 1 errori
# arm wrestling → chuckwagon racing  | 1 errori
# arm wrestling → harness racing  | 1 errori
# arm wrestling → rowing  | 1 errori
# arm wrestling → sumo wrestling  | 1 errori
# arm wrestling → trapeze  | 1 errori
# axe throwing → air hockey  | 1 errori
# axe throwing → gaga  | 1 errori
# axe throwing → ice climbing  | 1 errori
# axe throwing → shuffleboard  | 1 errori
# axe throwing → water polo  | 1 errori
#
# === Top confusions: PRE1_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (8, 8), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# table tennis → trapeze  | 3 errori
# baton twirling → ski jumping  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# bungee jumping → rock climbing  | 2 errori
# chuckwagon racing → hammer throw  | 2 errori
# figure skating pairs → trapeze  | 2 errori
# figure skating women → figure skating men  | 2 errori
# frisbee → sky surfing  | 2 errori
# ice climbing → disc golf  | 2 errori
# judo → trapeze  | 2 errori
# pommel horse → uneven bars  | 2 errori
# roller derby → chuckwagon racing  | 2 errori
# shot put → uneven bars  | 2 errori
# ski jumping → figure skating women  | 2 errori
# swimming → disc golf  | 2 errori
# ultimate → disc golf  | 2 errori
# uneven bars → trapeze  | 2 errori
# air hockey → mushing  | 1 errori
# air hockey → pole vault  | 1 errori
# air hockey → pommel horse  | 1 errori
# air hockey → trapeze  | 1 errori
# ampute football → bobsled  | 1 errori
# ampute football → bull riding  | 1 errori
# ampute football → sailboat racing  | 1 errori
# ampute football → uneven bars  | 1 errori
# ampute football → wheelchair racing  | 1 errori
# archery → log rolling  | 1 errori
# archery → volleyball  | 1 errori
# arm wrestling → fly fishing  | 1 errori
# arm wrestling → rowing  | 1 errori
#
# === Top confusions: PRE1_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# air hockey → croquet  | 2 errori
# bowling → harness racing  | 2 errori
# field hockey → mushing  | 2 errori
# giant slalom → bike polo  | 2 errori
# golf → chuckwagon racing  | 2 errori
# hang gliding → steer wrestling  | 2 errori
# high jump → mushing  | 2 errori
# horseshoe pitching → wheelchair racing  | 2 errori
# lacrosse → hurdles  | 2 errori
# mushing → bobsled  | 2 errori
# sailboat racing → fly fishing  | 2 errori
# ski jumping → baseball  | 2 errori
# surfing → fly fishing  | 2 errori
# tug of war → chuckwagon racing  | 2 errori
# ultimate → cricket  | 2 errori
# ultimate → disc golf  | 2 errori
# uneven bars → wheelchair basketball  | 2 errori
# air hockey → axe throwing  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → sumo wrestling  | 1 errori
# ampute football → bowling  | 1 errori
# ampute football → olympic wrestling  | 1 errori
# ampute football → snowmobile racing  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → swimming  | 1 errori
# archery → basketball  | 1 errori
# archery → billiards  | 1 errori
# archery → disc golf  | 1 errori
# archery → hydroplane racing  | 1 errori
# archery → surfing  | 1 errori
#
# === Top confusions: PRE1_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# bungee jumping → rock climbing  | 3 errori
# barell racing → axe throwing  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# canoe slamon → bmx  | 2 errori
# cheerleading → mushing  | 2 errori
# figure skating men → pole climbing  | 2 errori
# fly fishing → rock climbing  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# horse racing → cheerleading  | 2 errori
# jousting → mushing  | 2 errori
# judo → trapeze  | 2 errori
# log rolling → disc golf  | 2 errori
# mushing → bobsled  | 2 errori
# pole vault → track bicycle  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rowing → swimming  | 2 errori
# rugby → chuckwagon racing  | 2 errori
# steer wrestling → gaga  | 2 errori
# swimming → fly fishing  | 2 errori
# tennis → rings  | 2 errori
# uneven bars → trapeze  | 2 errori
# air hockey → bobsled  | 1 errori
# air hockey → croquet  | 1 errori
# air hockey → hammer throw  | 1 errori
# air hockey → horse jumping  | 1 errori
# air hockey → ski jumping  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → curling  | 1 errori
# ampute football → sailboat racing  | 1 errori
# ampute football → swimming  | 1 errori
#
# === Top confusions: PRE1_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# sumo wrestling → harness racing  | 3 errori
# basketball → hurdles  | 2 errori
# bike polo → rowing  | 2 errori
# bungee jumping → bmx  | 2 errori
# cheerleading → mushing  | 2 errori
# chuckwagon racing → sumo wrestling  | 2 errori
# fly fishing → swimming  | 2 errori
# golf → chuckwagon racing  | 2 errori
# hammer throw → horseshoe pitching  | 2 errori
# hang gliding → disc golf  | 2 errori
# hockey → bull riding  | 2 errori
# hydroplane racing → field hockey  | 2 errori
# ice climbing → tug of war  | 2 errori
# ice yachting → fly fishing  | 2 errori
# judo → hurdles  | 2 errori
# lacrosse → wheelchair racing  | 2 errori
# rugby → chuckwagon racing  | 2 errori
# shot put → cheerleading  | 2 errori
# swimming → fly fishing  | 2 errori
# tug of war → rowing  | 2 errori
# wheelchair basketball → disc golf  | 2 errori
# air hockey → balance beam  | 1 errori
# air hockey → bmx  | 1 errori
# air hockey → sumo wrestling  | 1 errori
# air hockey → ultimate  | 1 errori
# air hockey → water polo  | 1 errori
# ampute football → curling  | 1 errori
# ampute football → pommel horse  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → swimming  | 1 errori
#
# === Top confusions: PRE1_PCA1 | {'hog_orientations': 12, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (2, 2), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# bungee jumping → rock climbing  | 3 errori
# air hockey → hammer throw  | 2 errori
# barell racing → axe throwing  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# boxing → rugby  | 2 errori
# canoe slamon → bmx  | 2 errori
# cheerleading → mushing  | 2 errori
# chuckwagon racing → water polo  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# hockey → bull riding  | 2 errori
# horse racing → wheelchair racing  | 2 errori
# hurdles → wheelchair racing  | 2 errori
# judo → trapeze  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rowing → swimming  | 2 errori
# rugby → chuckwagon racing  | 2 errori
# sidecar racing → bobsled  | 2 errori
# swimming → rock climbing  | 2 errori
# tennis → rings  | 2 errori
# tug of war → disc golf  | 2 errori
# air hockey → bobsled  | 1 errori
# air hockey → croquet  | 1 errori
# air hockey → luge  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → curling  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → swimming  | 1 errori
# archery → log rolling  | 1 errori
# archery → volleyball  | 1 errori
# arm wrestling → barell racing  | 1 errori
#
# === Top confusions: PRE1_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} + LinearSVC ===
#
# Top 30 coppie più confuse:
#
# axe throwing → hammer throw  | 2 errori
# balance beam → cheerleading  | 2 errori
# balance beam → fly fishing  | 2 errori
# bmx → croquet  | 2 errori
# bobsled → cheerleading  | 2 errori
# bungee jumping → bmx  | 2 errori
# canoe slamon → bmx  | 2 errori
# field hockey → water polo  | 2 errori
# football → roller derby  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rowing → swimming  | 2 errori
# snowmobile racing → motorcycle racing  | 2 errori
# swimming → bobsled  | 2 errori
# track bicycle → volleyball  | 2 errori
# wheelchair basketball → disc golf  | 2 errori
# wheelchair racing → mushing  | 2 errori
# air hockey → giant slalom  | 1 errori
# air hockey → nascar racing  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → snowmobile racing  | 1 errori
# air hockey → sumo wrestling  | 1 errori
# ampute football → cheerleading  | 1 errori
# ampute football → curling  | 1 errori
# ampute football → steer wrestling  | 1 errori
# ampute football → swimming  | 1 errori
# archery → cheerleading  | 1 errori
# archery → disc golf  | 1 errori
# archery → mushing  | 1 errori
# archery → water cycling  | 1 errori
# arm wrestling → barell racing  | 1 errori
#
# === Top confusions: PRE1_PCA1 | {'hog_orientations': 9, 'hog_pixels_per_cell': (16, 16), 'hog_cells_per_block': (3, 3), 'hog_transform_sqrt': True} + LogReg ===
#
# Top 30 coppie più confuse:
#
# canoe slamon → bmx  | 3 errori
# barell racing → axe throwing  | 2 errori
# bungee jumping → rock climbing  | 2 errori
# fencing → horse jumping  | 2 errori
# figure skating men → bowling  | 2 errori
# figure skating men → pole climbing  | 2 errori
# horse racing → roller derby  | 2 errori
# judo → trapeze  | 2 errori
# pole climbing → trapeze  | 2 errori
# pole vault → track bicycle  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rowing → swimming  | 2 errori
# swimming → fly fishing  | 2 errori
# trapeze → giant slalom  | 2 errori
# weightlifting → trapeze  | 2 errori
# air hockey → nascar racing  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → sumo wrestling  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → hurdles  | 1 errori
# ampute football → swimming  | 1 errori
# archery → billiards  | 1 errori
# archery → rugby  | 1 errori
# arm wrestling → barell racing  | 1 errori
# arm wrestling → pommel horse  | 1 errori
# arm wrestling → sailboat racing  | 1 errori
# arm wrestling → sidecar racing  | 1 errori
# axe throwing → basketball  | 1 errori
# axe throwing → bungee jumping  | 1 errori
