# %% [markdown]
# # **Visual Information Processing and Management**
# ---
# ---
#
# Università degli Studi Milano Bicocca \
# CdLM Informatica — A.A 2025/2026
#
# ---
# ---
#
# ### **Componenti del gruppo:**
# — Oleksandra Golub (856706) \
# — Andrea Spagnolo (879254)

# %% [markdown]
# ## **Librerie**

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from PIL import Image, ImageOps
from dataclasses import dataclass
from typing import Dict, Any, List, Tuple

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.base import clone
from skimage import exposure
from skimage.restoration import denoise_bilateral
from sklearn.decomposition import PCA

from skimage.feature import hog, local_binary_pattern
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

from torchvision import datasets

# %% [markdown]
# ## **Configurazione**

# %%
@dataclass
class Config:
    # paths
    fit_dir  = "/kaggle/input/datasets/andreaspagnolo/visual-exam-dataset/visual_dataset/valid"
    #fit_dir: str = "/kaggle/input/visual-exam-dataset/visual_dataset/valid"
    test_dir = "/kaggle/input/datasets/andreaspagnolo/visual-exam-dataset/visual_dataset/test_degradato"
    #test_dir: str = "/kaggle/input/visual-exam-dataset/visual_dataset/test_degradato"
    
    img_size = 128   # per HOG spesso 128 va benissimo
    random_state = 42 # tuning
    max_iter = 50000 # tuning
    
def sanity_check_paths(cfg: Config):
    for p in [cfg.fit_dir, cfg.test_dir]:
        if not os.path.exists(p):
            raise FileNotFoundError(f"Path not found: {p}")
    print("OK paths")
    print("fit_dir:", cfg.fit_dir)
    print("test_dir:", cfg.test_dir)

# %% [markdown]
# ## **Feature Extraction**

# %%
def preprocess_gray(img_gray, use_preprocess):
    if not use_preprocess:
        return img_gray

    x = img_gray.astype(np.float32) / 255.0
    x = denoise_bilateral(x, sigma_color=0.05, sigma_spatial=2, channel_axis=None)
    x = exposure.equalize_adapthist(x, clip_limit=0.01)
    x = np.clip(x, 0, 1)
    return (x * 255).astype(np.uint8)


def extract_hog(path, cfg, hog_conf, use_preprocess):
    img = Image.open(path).convert("RGB")
    img = img.resize((cfg.img_size, cfg.img_size))
    gray = np.array(img.convert("L"))
    gray = preprocess_gray(gray, use_preprocess)

    return hog(
        gray,
        orientations=hog_conf["orient"],
        pixels_per_cell=hog_conf["ppc"],
        cells_per_block=hog_conf["cpb"],
        block_norm="L2-Hys",
        transform_sqrt=True,
        feature_vector=True
    ).astype(np.float32)

# %%
# (mini-cache in RAM per non rifare la stessa roba)
_feat_cache = {}

def build_xy(folder, cfg, hog_conf, use_preprocess):
    key = (id(folder), cfg.img_size, use_preprocess,
           hog_conf["orient"], hog_conf["ppc"], hog_conf["cpb"])

    if key in _feat_cache:
        return _feat_cache[key]

    X, y = [], []
    for path, label in folder.samples:
        X.append(extract_hog(path, cfg, hog_conf, use_preprocess))
        y.append(label)

    X = np.array(X)
    y = np.array(y)

    _feat_cache[key] = (X, y)
    return X, y

# %% [markdown]
# ## **Utils**

# %%
def print_top_confusions(cm, class_names, top_k=30):
    cm_no_diag = cm.copy()
    np.fill_diagonal(cm_no_diag, 0)

    pairs = []
    for i in range(len(class_names)):
        for j in range(len(class_names)):
            if i != j and cm_no_diag[i, j] > 0:
                pairs.append((i, j, cm_no_diag[i, j]))

    pairs_sorted = sorted(pairs, key=lambda x: x[2], reverse=True)

    print(f"\nTop {top_k} coppie più confuse:\n")
    for i, j, value in pairs_sorted[:top_k]:
        print(f"{class_names[i]} → {class_names[j]}  | {value} errori")


def build_model(model_name, C, use_pca=False, pca_n=256, max_iter=50000):
    steps = [("scaler", StandardScaler())]

    if use_pca:
        steps.append(("pca", PCA(n_components=pca_n, random_state=42)))

    if model_name == "LogReg":
        steps.append(("clf", LogisticRegression(max_iter=5000, C=C)))
    elif model_name == "LinearSVC":
        steps.append(("clf", LinearSVC(C=C, max_iter=max_iter)))
    else:
        raise ValueError("Model must be LogReg or LinearSVC")

    return Pipeline(steps)

# %% [markdown]
# ## **Migliori configurazioni**

# %%
BEST_CONFIGS: List[Dict[str, Any]] = [
    dict(
        tag="BEST_1",
        use_preprocess=False,
        use_pca=False,
        hog=dict(orient=12, ppc=(16,16), cpb=(2,2)),
        model="LogReg",
        C=0.1
    ),
    dict(
        tag="BEST_2",
        use_preprocess=True,
        use_pca=False,
        hog=dict(orient=9, ppc=(16,16), cpb=(3,3)),
        model="LogReg",
        C=3.0
    ),
    dict(
        tag="BEST_3",
        use_preprocess=False,
        use_pca=True,
        hog=dict(orient=12, ppc=(16,16), cpb=(2,2)),
        model="LogReg",
        C=3.0
    ),
]

# %% [markdown]
# ## **Main**

# %%
cfg = Config()
np.random.seed(cfg.random_state)
sanity_check_paths(cfg)
# Out:
# OK paths
# fit_dir: /kaggle/input/datasets/andreaspagnolo/visual-exam-dataset/visual_dataset/valid
# test_dir: /kaggle/input/datasets/andreaspagnolo/visual-exam-dataset/visual_dataset/test_degradato

# %%
fit_ds  = datasets.ImageFolder(cfg.fit_dir)
test_ds = datasets.ImageFolder(cfg.test_dir)

assert fit_ds.classes == test_ds.classes, "Class order diverso tra fit e test!"
class_names = fit_ds.classes

print("Num classes:", len(class_names))
print("Fit samples:", len(fit_ds))
print("Test samples:", len(test_ds))
# Out:
# Num classes: 100
# Fit samples: 500
# Test samples: 500

# %%
all_results = {}
cms = {}

for conf in BEST_CONFIGS:
    print("\n" + "="*60)
    print(f"RUN: {conf['tag']}")
    print("="*60)

    X_fit, y_fit = build_xy(fit_ds, cfg, conf["hog"], conf["use_preprocess"])
    X_test, y_test = build_xy(test_ds, cfg, conf["hog"], conf["use_preprocess"])

    model = build_model(
        conf["model"],
        C=conf["C"],
        use_pca=conf["use_pca"],
        max_iter=cfg.max_iter
    )

    model.fit(X_fit, y_fit)
    y_pred = model.predict(X_test)

    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred, average="macro", zero_division=0)
    cm = confusion_matrix(y_test, y_pred)

    print(f"Accuracy:  {acc:.4f}")
    print(f"Macro-F1:  {f1:.4f}")

    all_results[conf["tag"]] = {
        "acc": acc,
        "f1": f1,
        "C": conf["C"],
        "PCA": conf["use_pca"],
        "Pre": conf["use_preprocess"],
        "HOG": conf["hog"]
    }
    cms[conf["tag"]] = cm
# Out:
# ============================================================
# RUN: BEST_1
# ============================================================
# Accuracy:  0.1760
# Macro-F1:  0.1674
#
# ============================================================
# RUN: BEST_2
# ============================================================
# Accuracy:  0.1820
# Macro-F1:  0.1616
#
# ============================================================
# RUN: BEST_3
# ============================================================
# Accuracy:  0.1680
# Macro-F1:  0.1567

# %%
for tag, cm in cms.items():
    cm_norm = cm / np.maximum(cm.sum(axis=1, keepdims=True), 1)

    plt.figure(figsize=(12,10))
    sns.heatmap(cm_norm, cmap="viridis", xticklabels=False, yticklabels=False)
    plt.title(f"{tag} - Confusion Matrix")
    plt.show()

    print(f"\n=== Top confusions: {tag} ===")
    print_top_confusions(cm, class_names, top_k=30)
# Out:
# === Top confusions: BEST_1 ===
#
# Top 30 coppie più confuse:
#
# barell racing → axe throwing  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# canoe slamon → bmx  | 2 errori
# curling → field hockey  | 2 errori
# fly fishing → rowing  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# hockey → bull riding  | 2 errori
# jousting → mushing  | 2 errori
# judo → trapeze  | 2 errori
# log rolling → fly fishing  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rowing → swimming  | 2 errori
# sidecar racing → bobsled  | 2 errori
# air hockey → bobsled  | 1 errori
# air hockey → hammer throw  | 1 errori
# air hockey → nascar racing  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → basketball  | 1 errori
# ampute football → speed skating  | 1 errori
# ampute football → swimming  | 1 errori
# archery → horse racing  | 1 errori
# archery → log rolling  | 1 errori
# arm wrestling → pommel horse  | 1 errori
# arm wrestling → rock climbing  | 1 errori
# arm wrestling → sailboat racing  | 1 errori
# arm wrestling → sumo wrestling  | 1 errori
# axe throwing → air hockey  | 1 errori
# axe throwing → basketball  | 1 errori
# === Top confusions: BEST_2 ===
#
# Top 30 coppie più confuse:
#
# weightlifting → trapeze  | 3 errori
# barell racing → axe throwing  | 2 errori
# bungee jumping → rock climbing  | 2 errori
# canoe slamon → bmx  | 2 errori
# disc golf → croquet  | 2 errori
# figure skating men → bowling  | 2 errori
# figure skating men → pole climbing  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# horse racing → roller derby  | 2 errori
# judo → trapeze  | 2 errori
# olympic wrestling → field hockey  | 2 errori
# rock climbing → ice climbing  | 2 errori
# rowing → swimming  | 2 errori
# rugby → chuckwagon racing  | 2 errori
# ski jumping → arm wrestling  | 2 errori
# swimming → fly fishing  | 2 errori
# uneven bars → trapeze  | 2 errori
# air hockey → luge  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → trapeze  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → basketball  | 1 errori
# ampute football → field hockey  | 1 errori
# ampute football → swimming  | 1 errori
# ampute football → trapeze  | 1 errori
# archery → billiards  | 1 errori
# archery → rugby  | 1 errori
# arm wrestling → barell racing  | 1 errori
# arm wrestling → horseshoe pitching  | 1 errori
# === Top confusions: BEST_3 ===
#
# Top 30 coppie più confuse:
#
# tug of war → disc golf  | 3 errori
# axe throwing → air hockey  | 2 errori
# baseball → javelin  | 2 errori
# bike polo → motorcycle racing  | 2 errori
# canoe slamon → chuckwagon racing  | 2 errori
# chuckwagon racing → sumo wrestling  | 2 errori
# curling → field hockey  | 2 errori
# fly fishing → rowing  | 2 errori
# formula 1 racing → sidecar racing  | 2 errori
# hammer throw → sailboat racing  | 2 errori
# hockey → bull riding  | 2 errori
# horse racing → cheerleading  | 2 errori
# jousting → mushing  | 2 errori
# judo → trapeze  | 2 errori
# mushing → roller derby  | 2 errori
# pommel horse → tennis  | 2 errori
# rock climbing → ice climbing  | 2 errori
# swimming → rock climbing  | 2 errori
# volleyball → cheerleading  | 2 errori
# air hockey → bobsled  | 1 errori
# air hockey → hammer throw  | 1 errori
# air hockey → nascar racing  | 1 errori
# air hockey → sailboat racing  | 1 errori
# air hockey → tug of war  | 1 errori
# ampute football → barell racing  | 1 errori
# ampute football → basketball  | 1 errori
# ampute football → fly fishing  | 1 errori
# ampute football → speed skating  | 1 errori
# ampute football → swimming  | 1 errori
# archery → horse racing  | 1 errori

# %%
print("\n" + "="*60)
print("FINAL SUMMARY (TOP-3)")
print("="*60)

for tag, data in all_results.items():
    print(
        f"{tag:8} | "
        f"Acc={data['acc']:.4f} | "
        f"F1={data['f1']:.4f} | "
        f"C={data['C']} | "
        f"PCA={data['PCA']} | "
        f"Pre={data['Pre']} | "
        f"HOG={data['HOG']}"
    )
# Out:
# ============================================================
# FINAL SUMMARY (TOP-3)
# ============================================================
# BEST_1   | Acc=0.1760 | F1=0.1674 | C=0.1 | PCA=False | Pre=False | HOG={'orient': 12, 'ppc': (16, 16), 'cpb': (2, 2)}
# BEST_2   | Acc=0.1820 | F1=0.1616 | C=3.0 | PCA=False | Pre=True | HOG={'orient': 9, 'ppc': (16, 16), 'cpb': (3, 3)}
# BEST_3   | Acc=0.1680 | F1=0.1567 | C=3.0 | PCA=True | Pre=False | HOG={'orient': 12, 'ppc': (16, 16), 'cpb': (2, 2)}
